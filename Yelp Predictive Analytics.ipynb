# %% [markdown]
# # Machine Learning Mission: Predict Star Category Given a Yelp Review

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame

# %matplotlib inline
pd.options.display.mpl_style = 'default'

pd.set_option('display.max_columns', 36)
print pd.__version__
# Out:
# 0.15.1

# %% [markdown]
# First we'll use NLTK to preprocess and tokenize text data

# %%
import nltk
import string
from nltk import word_tokenize
from nltk.util import bigrams, trigrams
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from collections import Counter

nltk.download() # download the english stopwords corpus and the punkt package and maybe the porter stemmer if not present
# Out:
# showing info http://nltk.github.com/nltk_data/
# True

# %% [markdown]
# Download extra stopwords and sentiment/opinion datasets in case we may use it later on

# %%
# %%bash
# # thank you Kevin Bouge http://sites.google.com/site/kevinbouge/stopwords-lists
# wget --quiet --output-document=more_stopwords.txt http://sites.google.com/site/kevinbouge/stopwords-lists/stopwords_en.txt?attredirects=0&d=1
#
# # http://www2.cs.uic.edu/~liub/
# # Hu, Minqing, and Bing Liu. "Mining and summarizing customer reviews." Proceedings of the tenth ACM SIGKDD international conference on Knowledge discovery and data mining. ACM, 2004.
# # Liu, Bing, Minqing Hu, and Junsheng Cheng. "Opinion observer: analyzing and comparing opinions on the web." Proceedings of the 14th international conference on World Wide Web. ACM, 2005.
# wget --quiet --output-document=opinions.rar http://www.cs.uic.edu/~liub/FBS/opinion-lexicon-English.rar
# unrar e -o+ --silent opinions.rar > /dev/null
# sed -i '/^;/d' positive-words.txt
# sed -i '/^;/d' negative-words.txt

# %%
POSITIVE_WORDS = set([line.strip() for line in open('positive-words.txt', 'r')])
NEGATIVE_WORDS = set([line.strip() for line in open('negative-words.txt', 'r')])
NLTK_STOPWORDS = set(stopwords.words('english'))
MORE_STOPWORDS = set([line.strip() for line in open('more_stopwords.txt', 'r')])

def remove_numbers_in_string(s):
    return s.translate(None, string.digits)

def lowercase_remove_punctuation(s):
    s = s.lower()
    s = s.translate(None, string.punctuation)
    return s
    
def remove_stopwords(s):
    token_list = nltk.word_tokenize(s)
    exclude_stopwords = lambda token : token not in NLTK_STOPWORDS
    return ' '.join(filter(exclude_stopwords, token_list))

def filter_out_more_stopwords(token_list):
    return filter(lambda tok : tok not in MORE_STOPWORDS, token_list)

def stem_token_list(token_list):
    STEMMER = PorterStemmer()
    return [STEMMER.stem(tok.decode('utf-8')) for tok in token_list]

def restring_tokens(token_list):
    return ' '.join(token_list)

def lowercase_remove_punctuation_and_numbers_and_tokenize_and_filter_more_stopwords_and_stem_and_restring(s):
    s = remove_numbers_in_string(s)
    s = lowercase_remove_punctuation(s)
    s = remove_stopwords(s)
    token_list = nltk.word_tokenize(s)
    token_list = filter_out_more_stopwords(token_list)
    token_list = stem_token_list(token_list)
    return restring_tokens(token_list)

# %% [markdown]
# Use TURBO dataset from DataWrangling and EDA notebooks

# %%
turbo_csv_filename = os.path.join("./", 'TURBO_p1.csv')
TURBO_DF = pd.read_csv(turbo_csv_filename)
TURBO_DF.head()
# Out:
#                                           attributes             business_id  \
# 0  {u'Alcohol': u'full_bar', u'Noise Level': u'av...  mxrXVZWc6PWk81gvOVNOUw
# 1  {u'Alcohol': u'beer_and_wine', u'Noise Level':...  z3yFuLVrmH-3RJruPEMYKw
# 2  {u'Alcohol': u'beer_and_wine', u'Noise Level':...  z3yFuLVrmH-3RJruPEMYKw
# 3  {u'Alcohol': u'beer_and_wine', u'Noise Level':...  z3yFuLVrmH-3RJruPEMYKw
# 4  {u'Alcohol': u'beer_and_wine', u'Noise Level':...  z3yFuLVrmH-3RJruPEMYKw
#
#                                   categories        city  \
# 0      [American (Traditional), Restaurants]  Scottsdale
# 1  [Delis, Restaurants, Sandwiches, Italian]  Scottsdale
# 2  [Delis, Restaurants, Sandwiches, Italian]  Scottsdale
# 3  [Delis, Restaurants, Sandwiches, Italian]  Scottsdale
# 4  [Delis, Restaurants, Sandwiches, Italian]  Scottsdale
#
#                                         full_address  \
# 0  4800 N Scottsdale Rd\nSte 1700\nScottsdale, AZ...
# 1  2334 N Scottsdale Rd\nSte A133\nScottsdale, AZ...
# 2  2334 N Scottsdale Rd\nSte A133\nScottsdale, AZ...
# 3  2334 N Scottsdale Rd\nSte A133\nScottsdale, AZ...
# 4  2334 N Scottsdale Rd\nSte A133\nScottsdale, AZ...
#
#                                                hours   latitude   longitude  \
# 0  {u'Monday': {u'close': u'23:00', u'open': u'16...  33.508695 -111.927080
# 1  {u'Monday': {u'close': u'21:00', u'open': u'10...  33.474068 -111.927033
# 2  {u'Monday': {u'close': u'21:00', u'open': u'10...  33.474068 -111.927033
# 3  {u'Monday': {u'close': u'21:00', u'open': u'10...  33.474068 -111.927033
# 4  {u'Monday': {u'close': u'21:00', u'open': u'10...  33.474068 -111.927033
#
#                business_name neighborhoods  open  business_review_count  \
# 0               Roaring Fork            []  True                    463
# 1  Defalco's Italian Grocery            []  True                    469
# 2  Defalco's Italian Grocery            []  True                    469
# 3  Defalco's Italian Grocery            []  True                    469
# 4  Defalco's Italian Grocery            []  True                    469
#
#    business_stars state    type_x          review_date  \
# 0             4.0    AZ  business  2014-01-09 00:00:00
# 1             4.5    AZ  business  2010-08-08 00:00:00
# 2             4.5    AZ  business  2010-08-08 00:00:00
# 3             4.5    AZ  business  2010-08-08 00:00:00
# 4             4.5    AZ  business  2012-05-19 00:00:00
#
#                 review_id  review_stars  \
# 0  6fCJWrPiNmzOeqHccc7BUw             5
# 1  30yHYeC5uCeMB9lHU81EBQ             5
# 2  30yHYeC5uCeMB9lHU81EBQ             5
# 3  30yHYeC5uCeMB9lHU81EBQ             5
# 4  AvMyyevHBXOVm9NXEhDt_w             5
#
#                                          review_text  type_y  \
# 0  Awesome decor, great service, hidden gem in Sc...  review
# 1  I have been going to DeFalco's since 1984 when...  review
# 2  I have been going to DeFalco's since 1984 when...  review
# 3  I have been going to DeFalco's since 1984 when...  review
# 4  DeFalco's has been slowly perfecting their piz...  review
#
#                   user_id                             review_votes  \
# 0  jE5xVugujSaskAoh2DRx3Q  {u'funny': 0, u'useful': 0, u'cool': 0}
# 1  QnhQ8G51XbUpVEyWY2Km-A  {u'funny': 0, u'useful': 1, u'cool': 1}
# 2  QnhQ8G51XbUpVEyWY2Km-A  {u'funny': 0, u'useful': 1, u'cool': 1}
# 3  QnhQ8G51XbUpVEyWY2Km-A  {u'funny': 0, u'useful': 1, u'cool': 1}
# 4  QnhQ8G51XbUpVEyWY2Km-A  {u'funny': 0, u'useful': 0, u'cool': 0}
#
#    average_stars                                        compliments elite  \
# 0           3.65  {u'note': 1, u'funny': 1, u'writer': 2, u'plai...    []
# 1           4.25                                                 {}    []
# 2           4.25                                                 {}    []
# 3           4.25                                                 {}    []
# 4           4.25                                                 {}    []
#
#    fans                                            friends user_name  \
# 0     0  [5Fd93L51CcW9oiJxPPfgEQ, eKTZv1upkNLR5X2HSNd1f...         S
# 1     0                                                 []     David
# 2     0                                                 []     David
# 3     0                                                 []     David
# 4     0                                                 []     David
#
#    user_review_count type_x.1                                   user_votes  \
# 0                225     user  {u'funny': 36, u'useful': 135, u'cool': 29}
# 1                 11     user     {u'funny': 0, u'useful': 18, u'cool': 4}
# 2                 11     user     {u'funny': 0, u'useful': 18, u'cool': 4}
# 3                 11     user     {u'funny': 0, u'useful': 18, u'cool': 4}
# 4                 11     user     {u'funny': 0, u'useful': 18, u'cool': 4}
#
#   yelping_since             tip_date  likes  \
# 0       2011-02  2014-01-10 00:00:00      0
# 1       2009-08  2011-09-05 00:00:00      0
# 2       2009-08  2011-10-08 00:00:00      0
# 3       2009-08  2013-06-30 00:00:00      0
# 4       2009-08  2011-09-05 00:00:00      0
#
#                                             tip_text type_y.1
# 0         One of the best restaurants in Scottsdale.      tip
# 1  DeFalco's has a new pizza crust recipe, and no...      tip
# 2  Try the cappacola, hard salami, provolone sand...      tip
# 3  DeFalco's just introduced some great new dinne...      tip
# 4  DeFalco's has a new pizza crust recipe, and no...      tip

# %%
for idx in range(5):
    print TURBO_DF.review_text[idx]
    print
# Out:
# Awesome decor, great service, hidden gem in Scottsdale. Delicious and unique menu. The lamb fondue was so great, the trout, salads and chicken. Interesting bread basket with an assortment of muffins and breads and a diverse dessert menu. They need something a bit more chocolate on it ;)
# Great place!  One of the best restaurants I have been to in Scottsdale!!!
#
# I have been going to DeFalco's since 1984 when they were at the old location on 68th and Thomas. I have eaten at other Italian delis all over the Valley but this place has no rivals. The quality of the food is excellent, and the staff gets to know all of the customers as they continue to return. I highly recommend the Purista, CHP, cheese steak, Margerite pizza, the Tim's Special pizza, and the soups. Go for Italian items - they can't be beat. The wine selection is also fantastic. Tony DeFalco, the owner, tries every single wine before putting a bottle on the shelves, and he has fantastic wines from a number of regions. I can't say enough about this place. I eat here at least three times a week and have for many years. Healthy and delicious. Make sure to call orders in ahead as this place gets really busy. DeFalco's is a true desert classic with 100 year old recipes, some of friendliest staff around, and a dedication to excellence.
#
# I have been going to DeFalco's since 1984 when they were at the old location on 68th and Thomas. I have eaten at other Italian delis all over the Valley but this place has no rivals. The quality of the food is excellent, and the staff gets to know all of the customers as they continue to return. I highly recommend the Purista, CHP, cheese steak, Margerite pizza, the Tim's Special pizza, and the soups. Go for Italian items - they can't be beat. The wine selection is also fantastic. Tony DeFalco, the owner, tries every single wine before putting a bottle on the shelves, and he has fantastic wines from a number of regions. I can't say enough about this place. I eat here at least three times a week and have for many years. Healthy and delicious. Make sure to call orders in ahead as this place gets really busy. DeFalco's is a true desert classic with 100 year old recipes, some of friendliest staff around, and a dedication to excellence.
#
# I have been going to DeFalco's since 1984 when they were at the old location on 68th and Thomas. I have eaten at other Italian delis all over the Valley but this place has no rivals. The quality of the food is excellent, and the staff gets to know all of the customers as they continue to return. I highly recommend the Purista, CHP, cheese steak, Margerite pizza, the Tim's Special pizza, and the soups. Go for Italian items - they can't be beat. The wine selection is also fantastic. Tony DeFalco, the owner, tries every single wine before putting a bottle on the shelves, and he has fantastic wines from a number of regions. I can't say enough about this place. I eat here at least three times a week and have for many years. Healthy and delicious. Make sure to call orders in ahead as this place gets really busy. DeFalco's is a true desert classic with 100 year old recipes, some of friendliest staff around, and a dedication to excellence.
#
# DeFalco's has been slowly perfecting their pizza recipe for the last couple of years, and I can now say that their crust is one of my favorites in the Valley. I highly recommend trying one of their pizzas with the sweet Italian sausage. Heavenly.

# %%
initial_features = ['business_id', 'business_name', 'review_stars', 'review_text']
df_with_initial_features_and_preprocessed_review_text = TURBO_DF[initial_features]
# %time df_with_initial_features_and_preprocessed_review_text['review_text'] = df_with_initial_features_and_preprocessed_review_text['review_text'].apply(lowercase_remove_punctuation_and_numbers_and_tokenize_and_filter_more_stopwords_and_stem_and_restring)

for idx in range(5):
    print df_with_initial_features_and_preprocessed_review_text.review_text[idx]
    print
# Out:
# CPU times: user 1min 51s, sys: 164 ms, total: 1min 52s
# Wall time: 1min 52s
# awesom decor great servic hidden gem scottsdal delici uniqu menu lamb fondu great trout salad chicken interest bread basket assort muffin bread divers dessert menu bit chocol great place restaur scottsdal
#
# defalco locat thoma eaten italian deli valley place rival qualiti food excel staff custom continu return highli recommend purista chp chees steak margerit pizza tim special pizza soup italian item beat wine select fantast toni defalco owner singl wine put bottl shelv fantast wine number region place eat time week year healthi delici make call order ahead place busi defalco true desert classic year recip friendliest staff dedic excel
#
# defalco locat thoma eaten italian deli valley place rival qualiti food excel staff custom continu return highli recommend purista chp chees steak margerit pizza tim special pizza soup italian item beat wine select fantast toni defalco owner singl wine put bottl shelv fantast wine number region place eat time week year healthi delici make call order ahead place busi defalco true desert classic year recip friendliest staff dedic excel
#
# defalco locat thoma eaten italian deli valley place rival qualiti food excel staff custom continu return highli recommend purista chp chees steak margerit pizza tim special pizza soup italian item beat wine select fantast toni defalco owner singl wine put bottl shelv fantast wine number region place eat time week year healthi delici make call order ahead place busi defalco true desert classic year recip friendliest staff dedic excel
#
# defalco slowli perfect pizza recip coupl year crust favorit valley highli recommend pizza sweet italian sausag heavenli
# -c:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Next, import sklearn functions and partition the data into training and test subsets

# %%
from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import *
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, roc_auc_score

# %%
TEST_SIZE = 0.40
train_X, test_X, train_y, test_y = train_test_split(df_with_initial_features_and_preprocessed_review_text.review_text,
                                                    df_with_initial_features_and_preprocessed_review_text.review_stars,
                                                    test_size=TEST_SIZE,
                                                    random_state=42)

# %%
bag_of_words_vectorizer = CountVectorizer(analyzer = "word",
                                          tokenizer = None,    
                                          preprocessor = None,
                                          ngram_range = (1, 1),
                                          binary = False,
                                          strip_accents='unicode')

binary_vectorizer = CountVectorizer(analyzer = "word",
                                    tokenizer = None,    
                                    preprocessor = None,
                                    ngram_range = (1, 1),
                                    binary = True,
                                    strip_accents='unicode')

bigram_vectorizer = CountVectorizer(analyzer = "word",
                                    tokenizer = None,
                                    preprocessor = None,
                                    ngram_range = (2, 2),
                                    strip_accents='unicode')

trigram_vectorizer = CountVectorizer(analyzer = "word",
                                     tokenizer = None,
                                     preprocessor = None,
                                     ngram_range = (3, 3),
                                     strip_accents='unicode')

bi_and_trigram_vectorizer = CountVectorizer(analyzer = "word",
                                            tokenizer = None,
                                            preprocessor = None,
                                            ngram_range = (2,3),
                                            strip_accents='unicode')

random_forest_vectorizer = CountVectorizer(analyzer = "word",
                                           tokenizer = None,
                                           preprocessor = None,
                                           ngram_range = (1,1),
                                           strip_accents = 'unicode',
                                           max_features = 1000)

# %% [markdown]
# ### Bag of Words Model

# %% [markdown]
# Transform the Yelp reviews into feature vectors

# %%
bow_feature_matrix_train = bag_of_words_vectorizer.fit_transform(train_X)
bow_feature_matrix_test = bag_of_words_vectorizer.transform(test_X)
bow_feature_matrix_train, bow_feature_matrix_test
# Out:
# (<22094x29768 sparse matrix of type '<type 'numpy.int64'>'
#  	with 859870 stored elements in Compressed Sparse Row format>,
#  <14730x29768 sparse matrix of type '<type 'numpy.int64'>'
#  	with 565911 stored elements in Compressed Sparse Row format>)

# %% [markdown]
# Perform predictions for multinomial NB

# %%
multinomial_nb_classifier = MultinomialNB(fit_prior=True)
multinomial_nb_classifier.fit(bow_feature_matrix_train, train_y)
multinomial_nb_prediction = multinomial_nb_classifier.predict(bow_feature_matrix_test)

# %% [markdown]
# Visualize through Confusion Matrix

# %%
def make_confusion_matrix_relative(confusion_matrix):
    star_category_classes = [1, 2, 3, 4, 5]
    N = map(lambda clazz : sum(test_y == clazz), star_category_classes)
    relative_confusion_matrix = np.empty((len(star_category_classes), len(star_category_classes)))
    
    for j in range(0, len(star_category_classes)):
        if N[j] > 0:
            relative_frequency = confusion_matrix[j, :] / float(N[j])
            relative_confusion_matrix[j, :] = relative_frequency
            
    return relative_confusion_matrix

def plot_confusion_matrix(confusion_matrix=[[]], title='CM', savefilename=''):
    plt.matshow(make_confusion_matrix_relative(confusion_matrix), vmin=0, vmax=1)
    plt.title(title)
    plt.colorbar()
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.xticks(np.arange(5), np.arange(1,6))
    plt.yticks(np.arange(5), np.arange(1,6))

    if savefilename:
        plt.savefig(savefilename, bbox_inches='tight')
    
    return plt.show()

# %%
multinomial_confusion_matrix = confusion_matrix(test_y, multinomial_nb_prediction)
plot_confusion_matrix(multinomial_confusion_matrix, 'Multinomial Naive Bayes Confusion Matrix', savefilename='MultinomialCM.png')

# %% [markdown]
# Print classifier performance metrics

# %%
def print_classifier_performance_metrics(name, predictions):
    target_names = ['1 star', '2 star', '3 star', '4 star', '5 star']
    
    print "MODEL: %s" % name
    print

    print 'Precision: ' + str(metrics.precision_score(test_y, predictions))
    print 'Recall: ' + str(metrics.recall_score(test_y, predictions))
    print 'F1: ' + str(metrics.f1_score(test_y, predictions))
    print 'Accuracy: ' + str(metrics.accuracy_score(test_y, predictions))

    print
    print 'Classification Report:'
    print classification_report(test_y, predictions, target_names=target_names)
    
    print
    print 'Precision variance: %f' % np.var(precision_score(test_y, predictions, average=None), ddof=len(target_names)-1)
    
    print
    print 'Recall variance: %f' % np.var(recall_score(test_y, predictions, average=None), ddof=len(target_names)-1)

# %%
print_classifier_performance_metrics('Multinomial Naive Bayes', multinomial_nb_prediction)
# Out:
# MODEL: Multinomial Naive Bayes
#
# Precision: 0.58822847387
# Recall: 0.597827562797
# F1: 0.590812982183
# Accuracy: 0.597827562797
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.54      0.57      0.56       884
#      2 star       0.40      0.23      0.29       810
#      3 star       0.44      0.36      0.40      1965
#      4 star       0.55      0.58      0.56      4897
#      5 star       0.70      0.74      0.72      6174
#
# avg / total       0.59      0.60      0.59     14730
#
#
# Precision variance: 0.053976
#
# Recall variance: 0.161970

# %% [markdown]
# ### Bernoulli Naive Bayes Model

# %% [markdown]
# Transform Yelp Reviews into feature vectors by binarizing unigram occurrences

# %%
bernoulli_feature_matrix_train = binary_vectorizer.fit_transform(train_X)
bernoulli_feature_matrix_test = binary_vectorizer.transform(test_X)
bernoulli_feature_matrix_train, bernoulli_feature_matrix_test
# Out:
# (<39205x33377 sparse matrix of type '<type 'numpy.int64'>'
#  	with 3082931 stored elements in Compressed Sparse Row format>,
#  <14730x33377 sparse matrix of type '<type 'numpy.int64'>'
#  	with 1093800 stored elements in Compressed Sparse Row format>)

# %% [markdown]
# Make predictions with Bernoulli NB

# %%
bernoulli_nb_classifier = BernoulliNB().fit(bernoulli_feature_matrix_train, train_y)
bernoulli_nb_prediction = bernoulli_nb_classifier.predict(bernoulli_feature_matrix_test)

# %% [markdown]
# Visualize through confusion matrix

# %%
bernoulli_confusion_matrix = confusion_matrix(test_y, bernoulli_nb_prediction)
plot_confusion_matrix(bernoulli_confusion_matrix, 'Bernoulli Naive Bayes Confusion Matrix', savefilename='BernoulliCM.png')

# %%
print_classifier_performance_metrics('Bernoulli Naive Bayes', bernoulli_nb_prediction)
# Out:
# MODEL: Bernoulli Naive Bayes
#
# Precision: 0.559561448555
# Recall: 0.554921928038
# F1: 0.542512542207
# Accuracy: 0.554921928038
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.56      0.55      0.55       884
#      2 star       0.27      0.36      0.31       810
#      3 star       0.48      0.37      0.42      1965
#      4 star       0.61      0.39      0.47      4897
#      5 star       0.58      0.77      0.67      6174
#
# avg / total       0.56      0.55      0.54     14730
#
#
# Precision variance: 0.074526
#
# Recall variance: 0.126396

# %% [markdown]
# ### Bigram Naive Bayes Model

# %% [markdown]
# Transform Yelp reviews into feature vectorizers by counting bigram occurrences

# %%
bigram_multinomial_feature_matrix_train = bigram_vectorizer.fit_transform(train_X)
bigram_multinomial_feature_matrix_test = bigram_vectorizer.transform(test_X)
bigram_multinomial_feature_matrix_train, bigram_multinomial_feature_matrix_test
# Out:
# (<22094x438111 sparse matrix of type '<type 'numpy.int64'>'
#  	with 1010572 stored elements in Compressed Sparse Row format>,
#  <14730x438111 sparse matrix of type '<type 'numpy.int64'>'
#  	with 483725 stored elements in Compressed Sparse Row format>)

# %% [markdown]
# Make predictions with Bigram Multinomial NB

# %%
bigram_multinomial_nb_classifier = MultinomialNB().fit(bigram_multinomial_feature_matrix_train, train_y)
bigram_multinomial_nb_prediction = bigram_multinomial_nb_classifier.predict(bigram_multinomial_feature_matrix_test)

# %% [markdown]
# Visualize through confusion matrix

# %%
bigram_multinomial_confusion_matrix = confusion_matrix(test_y, bigram_multinomial_nb_prediction)
plot_confusion_matrix(bigram_multinomial_confusion_matrix, 'Bigram Multinomial Naive Bayes Confusion Matrix', savefilename='BigramMultinomialCM.png')

# %%
print_classifier_performance_metrics('Bigram Multinomial Naive Bayes', bigram_multinomial_nb_prediction)
# Out:
# MODEL: Bigram Multinomial Naive Bayes
#
# Precision: 0.683599596142
# Recall: 0.663679565513
# F1: 0.648118568318
# Accuracy: 0.663679565513
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.85      0.38      0.53       884
#      2 star       0.81      0.25      0.38       810
#      3 star       0.72      0.36      0.48      1965
#      4 star       0.58      0.72      0.64      4897
#      5 star       0.72      0.81      0.76      6174
#
# avg / total       0.68      0.66      0.65     14730
#
#
# Precision variance: 0.044846
#
# Recall variance: 0.242893

# %% [markdown]
# ### Trigram Naive Bayes Model

# %% [markdown]
# Transform Yelp reviews into feature vectorizers by counting bigram occurrences

# %%
trigram_multinomial_feature_matrix_train = trigram_vectorizer.fit_transform(train_X)
trigram_multinomial_feature_matrix_test = trigram_vectorizer.transform(test_X)
trigram_multinomial_feature_matrix_train, trigram_multinomial_feature_matrix_test
# Out:
# (<22094x680162 sparse matrix of type '<type 'numpy.int64'>'
#  	with 1006120 stored elements in Compressed Sparse Row format>,
#  <14730x680162 sparse matrix of type '<type 'numpy.int64'>'
#  	with 315097 stored elements in Compressed Sparse Row format>)

# %% [markdown]
# Make predictions with Trigram Multinomial NB

# %%
tri_gram_multinomial_nb_classifier = MultinomialNB().fit(trigram_multinomial_feature_matrix_train, train_y)
tri_gram_multinomial_nb_prediction = tri_gram_multinomial_nb_classifier.predict(trigram_multinomial_feature_matrix_test)

# %% [markdown]
# Visualize through confusion matrix

# %%
trigram_multinomial_confusion_matrix = confusion_matrix(test_y, tri_gram_multinomial_nb_prediction)
plot_confusion_matrix(trigram_multinomial_confusion_matrix, 'Trigram Multinomial Naive Bayes Confusion Matrix', savefilename='TrigramMultinomialCM.png')

# %%
print_classifier_performance_metrics('Trigram Multinomial Naive Bayes', tri_gram_multinomial_nb_prediction)
# Out:
# MODEL: Trigram Multinomial Naive Bayes
#
# Precision: 0.665759231175
# Recall: 0.63794976239
# F1: 0.61586076377
# Accuracy: 0.63794976239
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.86      0.26      0.40       884
#      2 star       0.84      0.24      0.38       810
#      3 star       0.73      0.35      0.47      1965
#      4 star       0.64      0.62      0.63      4897
#      5 star       0.61      0.85      0.71      6174
#
# avg / total       0.67      0.64      0.62     14730
#
#
# Precision variance: 0.049970
#
# Recall variance: 0.278052

# %% [markdown]
# ### Random Forest 100 Learners Model

# %%
forest100 = RandomForestClassifier(n_estimators = 100)

# %% [markdown]
# Transform Yelp reviews into feature vectors

# %%
random_forest_feature_matrix_train = random_forest_vectorizer.fit_transform(train_X)
random_forest_feature_matrix_test = random_forest_vectorizer.transform(test_X)

# %% [markdown]
# Make predictions with random forest set at 100 learners

# %%
# %time forest100.fit(random_forest_feature_matrix_train.toarray(), train_y)
forest100_pred = forest100.predict(random_forest_feature_matrix_test.toarray())
# Out:
# CPU times: user 3min 35s, sys: 556 ms, total: 3min 35s
# Wall time: 3min 38s

# %% [markdown]
# Visualize results in confusion matrix

# %%
random_forest_confusion_matrix = confusion_matrix(test_y, forest100_pred)
plot_confusion_matrix(random_forest_confusion_matrix, 'Random Forest (100 Learners) Confusion Matrix',
                      savefilename='RandomForestCM.png')

# %%
print_classifier_performance_metrics('Random Forest (100 Learners)', forest100_pred)
# Out:
# MODEL: Random Forest (100 Learners)
#
# Precision: 0.684051512922
# Recall: 0.68533604888
# F1: 0.67444978866
# Accuracy: 0.68533604888
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.66      0.63      0.64       884
#      2 star       0.75      0.27      0.40       810
#      3 star       0.65      0.45      0.53      1965
#      4 star       0.63      0.67      0.65      4897
#      5 star       0.73      0.84      0.78      6174
#
# avg / total       0.68      0.69      0.67     14730
#
#
# Precision variance: 0.010403
#
# Recall variance: 0.188566

# %% [markdown]
# ### SVC Model

# %%
svc_feature_matrix_train = random_forest_feature_matrix_train
svc_feature_matrix_test = random_forest_feature_matrix_test

svc = SVC()
# %time svc.fit(svc_feature_matrix_train, train_y) 
svc_predictions = svc.predict(svc_feature_matrix_test)

# %%
svc_confusion_matrix = confusion_matrix(test_y, svc_predictions)
plot_confusion_matrix(svc_confusion_matrix, 'SVC Confusion Matrix', savefilename='SVC_CM.png')

# %%
print_classifier_performance_metrics('SVC', svc_predictions)
# Out:
# MODEL: SVC
#
# Precision: 0.538277121141
# Recall: 0.517447386286
# F1: 0.446632174967
# Accuracy: 0.517447386286
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.67      0.17      0.27       884
#      2 star       0.69      0.04      0.07       810
#      3 star       0.58      0.01      0.03      1965
#      4 star       0.49      0.41      0.44      4897
#      5 star       0.52      0.88      0.66      6174
#
# avg / total       0.54      0.52      0.45     14730

# %% [markdown]
# ### Bigram-and-Trigram Model

# %% [markdown]
# Transform Yelp reviews into feature vectors

# %%
bi_and_trigram_multinomial_feature_matrix_train = bi_and_trigram_vectorizer.fit_transform(train_X)
bi_and_trigram_multinomial_feature_matrix_test = bi_and_trigram_vectorizer.transform(test_X)
bi_and_trigram_multinomial_feature_matrix_train, bi_and_trigram_multinomial_feature_matrix_test
# Out:
# (<22094x1118273 sparse matrix of type '<type 'numpy.int64'>'
#  	with 2016692 stored elements in Compressed Sparse Row format>,
#  <14730x1118273 sparse matrix of type '<type 'numpy.int64'>'
#  	with 798822 stored elements in Compressed Sparse Row format>)

# %% [markdown]
# Make predictions with Bi-Trigram Multinomial NB

# %%
bi_and_tri_gram_multinomial_nb_classifier = MultinomialNB().fit(bi_and_trigram_multinomial_feature_matrix_train, train_y)
bi_and_tri_gram_multinomial_nb_prediction = bi_and_tri_gram_multinomial_nb_classifier.predict(bi_and_trigram_multinomial_feature_matrix_test)

# %% [markdown]
# Visualize results in confusion matrix

# %%
bi_and_tri_gram_multinomial_confusion_matrix = confusion_matrix(test_y, bi_and_tri_gram_multinomial_nb_prediction)
plot_confusion_matrix(bi_and_tri_gram_multinomial_confusion_matrix,
                      'Bigram and Trigram Multinomial Naive Bayes Confusion Matrix', savefilename='BiAndTrigramMultinomialCM.png')

# %%
print_classifier_performance_metrics('Bi-and-Trigram Multinomial Naive Bayes', bi_and_tri_gram_multinomial_nb_prediction)
# Out:
# MODEL: Bi-and-Trigram Multinomial Naive Bayes
#
# Precision: 0.692929877095
# Recall: 0.66571622539
# F1: 0.649108368554
# Accuracy: 0.66571622539
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.89      0.36      0.52       884
#      2 star       0.88      0.25      0.38       810
#      3 star       0.75      0.35      0.48      1965
#      4 star       0.58      0.73      0.64      4897
#      5 star       0.71      0.82      0.76      6174
#
# avg / total       0.69      0.67      0.65     14730
#
#
# Precision variance: 0.066748
#
# Recall variance: 0.255295

# %% [markdown]
# ### Multinomial Naive Bayes

# %% [markdown]
# The probability that a document $d$ (a Yelp review) is a class $c$ (star category) is given by Bayes' Rule:
# $$\\$$
# $$P(c | d) = {{P(c) P(d | c) } \over P(d)}$$

# %% [markdown]
# The decision rule of the Naive Bayes model assigns the document to the class with the highest posterior probability, Maximum a posteriori (MAP):
# $$\\$$
# $$ \begin{align} c_{map} &= \underset{c} {\mathrm{argmax}} ~P(c | d) \\
#                          &= \underset{c} {\mathrm{argmax}} ~P(c) P(d | c) \\
#                          &= \underset{c} {\mathrm{argmax}} ~P(c) \prod_{1 \leq k \leq n_d} P(w_k | c) \\
#                          &= \underset{c} {\mathrm{argmax}} ~P(c) \prod_{w \in d} {P(w | c)}^{n_{wd}} \\
# \end{align} $$
# where <br />
# $w_k$ is the $k$th word in the document, <br />
# $n_d$ is the number of words in the document, and<br />
# $n_{wd}$ is the number of times word $w$ appears in the document

# %% [markdown]
# To prevent multiplication blowup and avoid potential floating point underflow, use the log probability: <br />
# $$\\$$
# $$ \begin{align} c_{map} &= \underset{c} {\mathrm{argmax}} {\text{ } \log \Big(~P(c) \prod_{w \in d} {P(w | c)}^{n_{wd}} \Big) }\\
#                          &= \underset{c} {\mathrm{argmax}} {\text{ } \log ~P(c) + \log \sum_{w \in d} {P(w | c)}^{n_{wd}} }\\
# \end{align} $$

# %% [markdown]
# With the Multinomial variation, the conditional probability of a word given a class according to : <br />
#
# $$\\$$
# $$ \begin{align}
#     P(w|c) &= { \sum_{d \in D_c} n_{wd} \over { \sum_{w' \in V} \sum_{d \in D_c}  n_{w'd}} } \\
#            &= { T_{wc} \over { \sum_{w' \in V} T_{w'c}} } \\
# \end{align} $$
#
# where $D_c$ is the set of all documents of class $c$, <br />
# and $T_{wc}$ is the number of times the word appears in $T$, the concatenation of documents in class $c$, <br />
# and $V$ is the vocabulary or the set of all words of all documents of all classes. <br /> <br />
# Sometimes Laplacian smoothing is used so that for words that do not appear, such as in situations like classifying unseen documents (the zero-frequency problem), we make sure to avoid operating on probability $\log$ 0. To do this we initialize each word count to be at least 1: <br /> <br />
#
# $$ \begin{align}
#     P(w|c) &= { 1 + T_{wc} \over { \sum_{w' \in V} ( 1 + T_{w'c}} ) } \\
#            &= { 1 + T_{wc} \over { |V| + \sum_{w' \in V} T_{w'c}} } \\
# \end{align} $$

# %%
from operator import itemgetter

def argmax(dictionary):
    return (max(dictionary.iteritems(), key=itemgetter(1)))[0]

class Multinomial_NB_Classifier():
    
    def train(self, class_labels, documents, class_priors=[], complement=False):       
        Classes = sorted(list(set(class_labels)))
        Vocabulary = reduce(lambda V, d : V.union(set(d.split())), documents, set())
        
        if len(class_priors) != len(Classes):
            N_documents_per_class = lambda c : sum(c == np.array(class_labels))
            N_documents = len(documents)
            class_priors = {c : N_documents_per_class(c) / float(N_documents) for c in Classes}
        
        Text_given_class = {c : documents[c == np.array(class_labels)].sum() for c in Classes}
        length_of_concatenated_documents_of_class = {c : len(Text_given_class[c].split()) for c in Classes}
        total_length_of_concatenated_documents_of_all_classes = sum([length_of_concatenated_documents_of_class[C] for C in Classes])
        
        absolute_frequency_vectorizer = CountVectorizer(analyzer = "word",
                                                        vocabulary = Vocabulary,
                                                        ngram_range = (1, 1),
                                                        binary = False)
        documentclass_termunigram_matrix = absolute_frequency_vectorizer.fit_transform(Text_given_class.values())
    
        number_of_feature_words = documentclass_termunigram_matrix.shape[1]
        feature_word_index = dict(zip(absolute_frequency_vectorizer.get_feature_names(), range(number_of_feature_words)))
        word_counts_irregardless_of_class = documentclass_termunigram_matrix.sum(axis=0)
        
        WORD_GIVEN_CLASS_CPT = {}
        COMPLEMENT_WORD_GIVEN_CLASS_CPT = {}
        K = len(Vocabulary)
        
        for class_idx, c in enumerate(Classes):
            if c not in WORD_GIVEN_CLASS_CPT:
                WORD_GIVEN_CLASS_CPT[c] = {}
                COMPLEMENT_WORD_GIVEN_CLASS_CPT[c] = {}

            for w in Vocabulary:
                T_wc = documentclass_termunigram_matrix[class_idx, feature_word_index[w]]
                WORD_GIVEN_CLASS_CPT[c][w] = float(1 + T_wc) / (K + length_of_concatenated_documents_of_class[c])
                
                C_wc = word_counts_irregardless_of_class[0, feature_word_index[w]] - T_wc
                complement_classes_wc = total_length_of_concatenated_documents_of_all_classes-length_of_concatenated_documents_of_class[c]
                COMPLEMENT_WORD_GIVEN_CLASS_CPT[c][w] = float(1 + C_wc) / (K + complement_classes_wc)
           
        self.classes = Classes
        self.vocabulary = Vocabulary
        self.class_priors = class_priors
        self.words_cpt = WORD_GIVEN_CLASS_CPT
        
        if complement:
            self.complement = True
            self.complement_cpt = COMPLEMENT_WORD_GIVEN_CLASS_CPT
        else:
            self.complement = False
            
        return self

    def predict(self, documents):
        target_labels = []
        
        for d in documents:
            score = {}
            Words_d = set(d.split())
            
            for class_idx, c in enumerate(self.classes):
                word_log_likelihoods = np.log([self.words_cpt[c][w] for w in Words_d if w in self.vocabulary])
                score[c] = np.log(self.class_priors[c])
                
                if self.complement:
                    word_in_complement_classes_log_likelihoods = np.log([self.complement_cpt[c][w] for w in Words_d if w in self.vocabulary])
                    score[c] -= sum(word_in_complement_classes_log_likelihoods)
                else:
                    score[c] += sum(word_log_likelihoods)
                    
            c_map = argmax(score)
            target_labels.append(c_map)
            
        return target_labels

# %%
# %time clf = Multinomial_NB_Classifier().train(class_labels=train_y, documents=train_X, complement=True)
# Out:
# CPU times: user 2min 24s, sys: 16.5 s, total: 2min 41s
# Wall time: 2min 41s

# %%
# %time pre = clf.predict(test_X)
# Out:
# CPU times: user 8.73 s, sys: 36 ms, total: 8.76 s
# Wall time: 8.72 s

# %%
my_multinomial_confusion_matrix = confusion_matrix(test_y, pre)
plot_confusion_matrix(my_multinomial_confusion_matrix,
                      'My Multinomial Naive Bayes Confusion Matrix', savefilename='MyMultinomialCM.png')

# %%
print_classifier_performance_metrics('My Multinomial Naive Bayes', pre)
# Out:
# MODEL: My Multinomial Naive Bayes
#
# Precision: 0.620820568443
# Recall: 0.617311608961
# F1: 0.593555240518
# Accuracy: 0.617311608961
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.63      0.46      0.53       884
#      2 star       0.79      0.15      0.26       810
#      3 star       0.59      0.26      0.36      1965
#      4 star       0.56      0.60      0.58      4897
#      5 star       0.66      0.82      0.73      6174
#
# avg / total       0.62      0.62      0.59     14730
#
#
# Precision variance: 0.031693
#
# Recall variance: 0.287326

# %% [markdown]
# ### Top 10 Features for each Star Category of Bag of Words Multinomial NB

# %%
N = 10
vocab = np.array([t for t, i in sorted(bag_of_words_vectorizer.vocabulary_.iteritems(), key=itemgetter(1))])

for i, label in enumerate(sorted(set(train_y))):
 top_n_features_indices = np.argsort(multinomial_nb_classifier.coef_[i])[-N:]
 print "\nThe top %d most informative features for star category %d: \n%s" % (N, label, ", ".join(vocab[top_n_features_indices]))
# Out:
# The top 10 most informative features for star category 1:
# order, servic, hate, wrong, food, time, place, rude, worst, bad
#
# The top 10 most informative features for star category 2:
# lack, hard, servic, good, disappoint, order, food, time, place, bad
#
# The top 10 most informative features for star category 3:
# order, cheap, hard, problem, time, fri, place, food, good, bad
#
# The top 10 most informative features for star category 4:
# servic, love, hard, bad, time, great, fri, food, place, good
#
# The top 10 most informative features for star category 5:
# hard, servic, bad, time, fri, good, love, food, great, place

# %% [markdown]
# ### Top 10 Features for each Star Category of Bigram Multinomial NB

# %%
N = 10
vocab = np.array([t for t, i in sorted(bigram_vectorizer.vocabulary_.iteritems(), key=itemgetter(1))])

for i, label in enumerate(sorted(set(train_y))):
 top_n_features_indices = np.argsort(bigram_multinomial_nb_classifier.coef_[i])[-N:]
 print "\nThe top %d most informative features for star category %d: \n%s" % (N, label, ", ".join(vocab[top_n_features_indices]))
# Out:
# The top 10 most informative features for star category 1:
# come back, wast time, dont care, give star, la vega, wont back, wait minut, front desk, park lot, custom servic
#
# The top 10 most informative features for star category 2:
# servic good, dim sum, give star, la vega, good food, park lot, food good, happi hour, pretti good, custom servic
# The top 10 most informative features for star category 3:
# staff friendli, lunch special, late night, slot machin, fast food, custom servic, happi hour, food good, la vega, pretti good
#
# The top 10 most informative features for star category 4:
# servic good, great food, love place, staff friendli, good food, food good, great place, la vega, pretti good, happi hour
# The top 10 most informative features for star category 5:
# food great, custom servic, staff friendli, happi hour, highli recommend, great servic, great food, great place, la vega, love place

# %% [markdown]
# ### ReFeature Engineering to Improve Classifier Accuracy

# %%
import json
from collections import OrderedDict
 
def convert_json_dict_string_to_python_dict(json_string_dict):
    return json.loads(json_string_dict.replace('\'', '"').replace('u"', '"'))

def get_number_of_review_votes_that_are(cool_or_funny_or_useful):
    assert cool_or_funny_or_useful in ['cool', 'funny', 'useful']
    return lambda review_votes_dict : review_votes_dict[cool_or_funny_or_useful]

def get_total_review_votes(review_votes_dict):
    return review_votes_dict['cool'] + review_votes_dict['funny'] + review_votes_dict['useful']

def get_number_of_compliments_that_are(cool_or_cute_or_funny_or_hot_or_list_or_more_or_note_or_photos_or_plain_or_profile_or_writer):
    key = cool_or_cute_or_funny_or_hot_or_list_or_more_or_note_or_photos_or_plain_or_profile_or_writer
    assert cool_or_cute_or_funny_or_hot_or_list_or_more_or_note_or_photos_or_plain_or_profile_or_writer in [u'cool',
                                                                                                            u'cute',
                                                                                                            u'funny',
                                                                                                            u'hot',
                                                                                                            u'list',
                                                                                                            u'more',
                                                                                                            u'note',
                                                                                                            u'photos',
                                                                                                            u'plain',
                                                                                                            u'profile',
                                                                                                            u'writer']
    return lambda compliments_dict : compliments_dict[key] if key in compliments_dict else 0

def count_number_of_positive_words(document):
    return len(filter(lambda tok : tok in POSITIVE_WORDS, document.split()))

def count_number_of_negative_words(document):
    return len(filter(lambda tok : tok in NEGATIVE_WORDS, document.split()))

def check_that_userid_does_not_appear_in_its_friendid_list(df):
    for i, x in df.iterrows():
        d = OrderedDict(x)
        assert d['business_id'] not in d['friends_id_list']

def get_average_friends_average_stars(df):
    
    def apply_func(friend_user_id_list):
        friend_ids_that_exist_in_df = set(df['user_id']).intersection(set(friend_user_id_list))
        indices_of_records_with_friend_ids = df['user_id'].isin(friend_ids_that_exist_in_df)
        userid_and_averagestars_df = df[['user_id', 'user_average_stars']]
        friends_average_stars_indexed_by_userid_df = userid_and_averagestars_df.loc[indices_of_records_with_friend_ids].groupby('user_id').mean()
        return np.mean(friends_average_stars_indexed_by_userid_df['user_average_stars'])
    
    return apply_func

# %%
df_with_refeature_engineered = df_with_initial_features_and_preprocessed_review_text
df_with_refeature_engineered['review_votes'] = TURBO_DF.review_votes.apply(convert_json_dict_string_to_python_dict)
df_with_refeature_engineered['review_cool'] = df_with_refeature_engineered.review_votes.apply(get_number_of_review_votes_that_are('cool'))
df_with_refeature_engineered['review_funny'] = df_with_refeature_engineered.review_votes.apply(get_number_of_review_votes_that_are('funny'))
df_with_refeature_engineered['review_useful'] = df_with_refeature_engineered.review_votes.apply(get_number_of_review_votes_that_are('useful'))
df_with_refeature_engineered['review_votes_count'] = df_with_refeature_engineered.review_votes.apply(get_total_review_votes)
df_with_refeature_engineered['review_length'] = df_with_refeature_engineered.review_text.apply(len)

df_with_refeature_engineered['user_id'] = TURBO_DF.user_id
df_with_refeature_engineered['user_votes'] = TURBO_DF.user_votes.apply(convert_json_string_review_votes_to_dict)
df_with_refeature_engineered['user_cool'] = df_with_refeature_engineered.user_votes.apply(get_number_of_review_votes_that_are('cool'))
df_with_refeature_engineered['user_funny'] = df_with_refeature_engineered.user_votes.apply(get_number_of_review_votes_that_are('funny'))
df_with_refeature_engineered['user_useful'] = df_with_refeature_engineered.user_votes.apply(get_number_of_review_votes_that_are('useful'))
df_with_refeature_engineered['user_votes_count'] = df_with_refeature_engineered.user_votes.apply(get_total_review_votes)
df_with_refeature_engineered['user_review_count'] = TURBO_DF.user_review_count
df_with_refeature_engineered['user_fans'] = TURBO_DF.fans
df_with_refeature_engineered['user_friends_count'] = TURBO_DF.friends.apply(len)
df_with_refeature_engineered['user_years_elite_count'] = TURBO_DF.elite.apply(len)
df_with_refeature_engineered['user_compliments'] = TURBO_DF.compliments.apply(convert_json_dict_string_to_python_dict)
df_with_refeature_engineered['user_compliments_cool'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('cool'))
df_with_refeature_engineered['user_compliments_cute'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('cute'))
df_with_refeature_engineered['user_compliments_funny'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('funny'))
df_with_refeature_engineered['user_compliments_hot'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('hot'))
df_with_refeature_engineered['user_compliments_list'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('list'))
df_with_refeature_engineered['user_compliments_more'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('more'))
df_with_refeature_engineered['user_compliments_note'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('note'))
df_with_refeature_engineered['user_compliments_photos'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('photos'))
df_with_refeature_engineered['user_compliments_plain'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('plain'))
df_with_refeature_engineered['user_compliments_profile'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('profile'))
df_with_refeature_engineered['user_compliments_writer'] = df_with_refeature_engineered.user_compliments.apply(get_number_of_compliments_that_are('writer'))

df_with_refeature_engineered['user_average_stars'] = TURBO_DF.average_stars
df_with_refeature_engineered['business_stars'] = TURBO_DF.business_stars

df_with_refeature_engineered['positive_words_count'] = TURBO_DF.review_text.apply(count_number_of_positive_words)
df_with_refeature_engineered['negative_words_count'] = TURBO_DF.review_text.apply(count_number_of_negative_words)
df_with_refeature_engineered['neutral_words_count'] = df_with_refeature_engineered.review_length - (df_with_refeature_engineered.positive_words_count + df_with_refeature_engineered.negative_words_count)
df_with_refeature_engineered['positive_words_count_over_review_length'] = df_with_refeature_engineered.positive_words_count / (1.0*df_with_refeature_engineered.review_length)
df_with_refeature_engineered['negative_words_count_over_review_length'] = df_with_refeature_engineered.negative_words_count / (1.0*df_with_refeature_engineered.review_length)
df_with_refeature_engineered['neutral_words_count_over_review_length'] = df_with_refeature_engineered.neutral_words_count / (1.0*df_with_refeature_engineered.review_length)
df_with_refeature_engineered['positive_to_negative_words_count_ratio'] = df_with_refeature_engineered.positive_words_count / (1.0*df_with_refeature_engineered.negative_words_count)
df_with_refeature_engineered['negative_to_positive_words_count_ratio'] = df_with_refeature_engineered.negative_words_count / (1.0*df_with_refeature_engineered.positive_words_count)

df_with_refeature_engineered['friends_id_list'] = TURBO_DF.friends.apply(lambda s : s.replace('[', '').replace(']','').split(', '))
check_that_userid_does_not_appear_in_its_friendid_list(df_with_refeature_engineered)
df_with_refeature_engineered['friends_average_stars'] = df_with_refeature_engineered.friends_id_list.apply(get_average_friends_average_stars(df_with_refeature_engineered))
# Out:
# -c:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# -c:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
corr_features = ['review_cool', 'review_funny', 'review_useful', 'review_votes_count', 'review_length',
                 'business_review_count',
                 'user_cool', 'user_funny', 'user_useful', 'user_votes_count', 'user_review_count', 'user_fans',
                 'user_friends_count', 'user_years_elite_count', 'user_compliments_cool', 'user_compliments_cool',
                 'user_compliments_cute', 'user_compliments_funny', 'user_compliments_hot', 'user_compliments_list',
                 'user_compliments_more', 'user_compliments_note', 'user_compliments_photos', 'user_compliments_plain',
                 'user_compliments_profile', 'user_compliments_writer',
                 'positive_words_count', 'negative_words_count', 'positive_to_negative_words_count_ratio',
                 'negative_to_positive_words_count_ratio', 'neutral_words_count', 'neutral_words_count_over_review_length',
                 'positive_words_count_over_review_length', 'negative_words_count_over_review_length', 'friends_average_stars',
              ,
                 'user_average_stars', 'business_stars', 'review_stars']
Corr_df = df_with_refeature_engineered[corr_features].corr()
Corr_df
# Out:
#                                          review_cool  review_funny  \
# review_cool                                 1.000000      0.876986
# review_funny                                0.876986      1.000000
# review_useful                               0.905377      0.836133
# review_votes_count                          0.969035      0.938526
# review_length                               0.370882      0.334169
# business_review_count                       0.067087      0.063110
# user_cool                                   0.532876      0.453437
# user_funny                                  0.539856      0.477724
# user_useful                                 0.526828      0.445406
# user_votes_count                            0.534600      0.458558
# user_review_count                           0.369892      0.297208
# user_fans                                   0.456461      0.380283
# user_friends_count                          0.422400      0.358390
# user_years_elite_count                      0.369400      0.315372
# user_compliments_cool                       0.477984      0.415553
# user_compliments_cool                       0.477984      0.415553
# user_compliments_cute                       0.383362      0.320910
# user_compliments_funny                      0.458846      0.425514
# user_compliments_hot                        0.475412      0.419562
# user_compliments_list                       0.383524      0.316933
# user_compliments_more                       0.457428      0.399300
# user_compliments_note                       0.501344      0.437117
# user_compliments_photos                     0.380861      0.327153
# user_compliments_plain                      0.479592      0.411991
# user_compliments_profile                    0.382522      0.328254
# user_compliments_writer                     0.445645      0.388071
# positive_words_count                        0.304234      0.256926
# negative_words_count                        0.217139      0.261001
# positive_to_negative_words_count_ratio      0.108747      0.030383
# negative_to_positive_words_count_ratio      0.025659      0.069877
# neutral_words_count                         0.371140      0.334183
# neutral_words_count_over_review_length      0.063946      0.048867
# positive_words_count_over_review_length    -0.068285     -0.075128
# negative_words_count_over_review_length     0.001280      0.047499
# friends_average_stars                      -0.091877     -0.081851
# user_average_stars                          0.015025     -0.012673
# business_stars                              0.053364      0.004600
# review_stars                                0.046922     -0.023778
#
#                                          review_useful  review_votes_count  \
# review_cool                                   0.905377            0.969035
# review_funny                                  0.836133            0.938526
# review_useful                                 1.000000            0.961666
# review_votes_count                            0.961666            1.000000
# review_length                                 0.420021            0.395431
# business_review_count                         0.050268            0.062210
# user_cool                                     0.506119            0.521383
# user_funny                                    0.511395            0.533405
# user_useful                                   0.504916            0.516358
# user_votes_count                              0.509235            0.524794
# user_review_count                             0.363646            0.361306
# user_fans                                     0.442274            0.447526
# user_friends_count                            0.429509            0.424145
# user_years_elite_count                        0.373622            0.370747
# user_compliments_cool                         0.452379            0.469796
# user_compliments_cool                         0.452379            0.469796
# user_compliments_cute                         0.354063            0.369472
# user_compliments_funny                        0.440565            0.461774
# user_compliments_hot                          0.445449            0.467442
# user_compliments_list                         0.355739            0.368947
# user_compliments_more                         0.432569            0.449957
# user_compliments_note                         0.481452            0.495897
# user_compliments_photos                       0.348418            0.368347
# user_compliments_plain                        0.455665            0.470525
# user_compliments_profile                      0.355578            0.372078
# user_compliments_writer                       0.422212            0.438382
# positive_words_count                          0.327521            0.312286
# negative_words_count                          0.271627            0.262063
# positive_to_negative_words_count_ratio        0.097742            0.084125
# negative_to_positive_words_count_ratio        0.055222            0.052221
# neutral_words_count                           0.420397            0.395672
# neutral_words_count_over_review_length        0.082764            0.069530
# positive_words_count_over_review_length      -0.095917           -0.084384
# negative_words_count_over_review_length       0.016938            0.021942
# friends_average_stars                        -0.098597           -0.095349
# user_average_stars                           -0.007227           -0.001731
# business_stars                                0.038117            0.034515
# review_stars                                 -0.011676            0.003824
#
#                                          review_length  business_review_count  \
# review_cool                                   0.370882               0.067087
# review_funny                                  0.334169               0.063110
# review_useful                                 0.420021               0.050268
# review_votes_count                            0.395431               0.062210
# review_length                                 1.000000               0.117596
# business_review_count                         0.117596               1.000000
# user_cool                                     0.281686               0.075412
# user_funny                                    0.281573               0.083580
# user_useful                                   0.294221               0.075261
# user_votes_count                              0.287954               0.077827
# user_review_count                             0.296254               0.102535
# user_fans                                     0.267921               0.077040
# user_friends_count                            0.349549               0.039905
# user_years_elite_count                        0.338430               0.086826
# user_compliments_cool                         0.260306               0.080616
# user_compliments_cool                         0.260306               0.080616
# user_compliments_cute                         0.172632               0.070775
# user_compliments_funny                        0.227607               0.060304
# user_compliments_hot                          0.250540               0.094824
# user_compliments_list                         0.210610               0.069087
# user_compliments_more                         0.238240               0.065524
# user_compliments_note                         0.248070               0.050087
# user_compliments_photos                       0.164681               0.047528
# user_compliments_plain                        0.255720               0.075320
# user_compliments_profile                      0.185136               0.052991
# user_compliments_writer                       0.268222               0.082111
# positive_words_count                          0.825695               0.085800
# negative_words_count                          0.671498               0.111773
# positive_to_negative_words_count_ratio        0.260502              -0.024734
# negative_to_positive_words_count_ratio        0.099028               0.064980
# neutral_words_count                           0.999948               0.117525
# neutral_words_count_over_review_length        0.152094               0.031155
# positive_words_count_over_review_length      -0.168960              -0.052747
# negative_words_count_over_review_length       0.016315               0.040118
# friends_average_stars                        -0.069091              -0.045210
# user_average_stars                           -0.048303              -0.013404
# business_stars                                0.039988               0.055143
# review_stars                                 -0.064584              -0.017451
#
#                                          user_cool  user_funny  user_useful  \
# review_cool                               0.532876    0.539856     0.526828
# review_funny                              0.453437    0.477724     0.445406
# review_useful                             0.506119    0.511395     0.504916
# review_votes_count                        0.521383    0.533405     0.516358
# review_length                             0.281686    0.281573     0.294221
# business_review_count                     0.075412    0.083580     0.075261
# user_cool                                 1.000000    0.986511     0.994557
# user_funny                                0.986511    1.000000     0.976907
# user_useful                               0.994557    0.976907     1.000000
# user_votes_count                          0.998638    0.990495     0.996476
# user_review_count                         0.766573    0.729569     0.811831
# user_fans                                 0.839932    0.803273     0.856334
# user_friends_count                        0.397707    0.384959     0.429716
# user_years_elite_count                    0.471788    0.451559     0.503421
# user_compliments_cool                     0.921460    0.929047     0.901122
# user_compliments_cool                     0.921460    0.929047     0.901122
# user_compliments_cute                     0.667963    0.662857     0.650150
# user_compliments_funny                    0.780427    0.807225     0.774767
# user_compliments_hot                      0.883897    0.901085     0.858735
# user_compliments_list                     0.777342    0.774273     0.764286
# user_compliments_more                     0.852654    0.870028     0.830431
# user_compliments_note                     0.896483    0.897102     0.892265
# user_compliments_photos                   0.690787    0.700297     0.664161
# user_compliments_plain                    0.924843    0.922697     0.920342
# user_compliments_profile                  0.731807    0.746827     0.705655
# user_compliments_writer                   0.886480    0.900498     0.867690
# positive_words_count                      0.231146    0.230280     0.239385
# negative_words_count                      0.142071    0.153218     0.153730
# positive_to_negative_words_count_ratio    0.087232    0.074661     0.089834
# negative_to_positive_words_count_ratio    0.010086    0.017097     0.016315
# neutral_words_count                       0.282057    0.281870     0.294601
# neutral_words_count_over_review_length    0.071074    0.067037     0.075079
# positive_words_count_over_review_length  -0.068037   -0.067318    -0.073609
# negative_words_count_over_review_length  -0.014514   -0.007311    -0.011807
# friends_average_stars                    -0.109227   -0.106048    -0.118901
# user_average_stars                       -0.014376   -0.025143    -0.020888
# business_stars                            0.016211    0.008194     0.016897
# review_stars                             -0.019483   -0.025592    -0.023706
#
#                                          user_votes_count  user_review_count  \
# review_cool                                      0.534600           0.369892
# review_funny                                     0.458558           0.297208
# review_useful                                    0.509235           0.363646
# review_votes_count                               0.524794           0.361306
# review_length                                    0.287954           0.296254
# business_review_count                            0.077827           0.102535
# user_cool                                        0.998638           0.766573
# user_funny                                       0.990495           0.729569
# user_useful                                      0.996476           0.811831
# user_votes_count                                 1.000000           0.778495
# user_review_count                                0.778495           1.000000
# user_fans                                        0.840608           0.729545
# user_friends_count                               0.409032           0.556553
# user_years_elite_count                           0.481321           0.656834
# user_compliments_cool                            0.919273           0.613655
# user_compliments_cool                            0.919273           0.613655
# user_compliments_cute                            0.662351           0.452379
# user_compliments_funny                           0.788598           0.567605
# user_compliments_hot                             0.882118           0.575979
# user_compliments_list                            0.774666           0.544242
# user_compliments_more                            0.851974           0.543224
# user_compliments_note                            0.898868           0.641885
# user_compliments_photos                          0.685554           0.403341
# user_compliments_plain                           0.926512           0.654710
# user_compliments_profile                         0.728392           0.422461
# user_compliments_writer                          0.886454           0.592670
# positive_words_count                             0.235259           0.237500
# negative_words_count                             0.150331           0.169771
# positive_to_negative_words_count_ratio           0.085302           0.088351
# negative_to_positive_words_count_ratio           0.014488           0.039216
# neutral_words_count                              0.288311           0.296580
# neutral_words_count_over_review_length           0.071943           0.078907
# positive_words_count_over_review_length         -0.070397          -0.085807
# negative_words_count_over_review_length         -0.011592           0.004714
# friends_average_stars                           -0.112775          -0.149040
# user_average_stars                              -0.019898          -0.045239
# business_stars                                   0.014453           0.006648
# review_stars                                    -0.022879          -0.036686
#
#                                          user_fans  user_friends_count  \
# review_cool                               0.456461            0.422400
# review_funny                              0.380283            0.358390
# review_useful                             0.442274            0.429509
# review_votes_count                        0.447526            0.424145
# review_length                             0.267921            0.349549
# business_review_count                     0.077040            0.039905
# user_cool                                 0.839932            0.397707
# user_funny                                0.803273            0.384959
# user_useful                               0.856334            0.429716
# user_votes_count                          0.840608            0.409032
# user_review_count                         0.729545            0.556553
# user_fans                                 1.000000            0.409182
# user_friends_count                        0.409182            1.000000
# user_years_elite_count                    0.504711            0.644666
# user_compliments_cool                     0.712853            0.305438
# user_compliments_cool                     0.712853            0.305438
# user_compliments_cute                     0.617142            0.241940
# user_compliments_funny                    0.589908            0.334122
# user_compliments_hot                      0.691597            0.290847
# user_compliments_list                     0.651782            0.242534
# user_compliments_more                     0.615624            0.287337
# user_compliments_note                     0.750927            0.362669
# user_compliments_photos                   0.445215            0.182910
# user_compliments_plain                    0.808732            0.319437
# user_compliments_profile                  0.501927            0.199160
# user_compliments_writer                   0.673640            0.284190
# positive_words_count                      0.232298            0.305383
# negative_words_count                      0.139615            0.228213
# positive_to_negative_words_count_ratio    0.103999            0.133103
# negative_to_positive_words_count_ratio    0.014299            0.044295
# neutral_words_count                       0.268034            0.349305
# neutral_words_count_over_review_length    0.061888            0.061600
# positive_words_count_over_review_length  -0.060839           -0.075364
# negative_words_count_over_review_length  -0.009403            0.020664
# friends_average_stars                    -0.105497           -0.146398
# user_average_stars                        0.022053            0.022297
# business_stars                            0.034554            0.024949
# review_stars                              0.001371            0.011285
#
#                                          user_years_elite_count  \
# review_cool                                            0.369400
# review_funny                                           0.315372
# review_useful                                          0.373622
# review_votes_count                                     0.370747
# review_length                                          0.338430
# business_review_count                                  0.086826
# user_cool                                              0.471788
# user_funny                                             0.451559
# user_useful                                            0.503421
# user_votes_count                                       0.481321
# user_review_count                                      0.656834
# user_fans                                              0.504711
# user_friends_count                                     0.644666
# user_years_elite_count                                 1.000000
# user_compliments_cool                                  0.352188
# user_compliments_cool                                  0.352188
# user_compliments_cute                                  0.299867
# user_compliments_funny                                 0.366383
# user_compliments_hot                                   0.344654
# user_compliments_list                                  0.297389
# user_compliments_more                                  0.321576
# user_compliments_note                                  0.406812
# user_compliments_photos                                0.188650
# user_compliments_plain                                 0.367611
# user_compliments_profile                               0.223506
# user_compliments_writer                                0.326035
# positive_words_count                                   0.288254
# negative_words_count                                   0.205742
# positive_to_negative_words_count_ratio                 0.131991
# negative_to_positive_words_count_ratio                 0.039912
# neutral_words_count                                    0.338432
# neutral_words_count_over_review_length                 0.095208
# positive_words_count_over_review_length               -0.103413
# negative_words_count_over_review_length                0.005444
# friends_average_stars                                 -0.126430
# user_average_stars                                     0.004374
# business_stars                                         0.052868
# review_stars                                           0.003875
#
#                                          user_compliments_cool  \
# review_cool                                           0.477984
# review_funny                                          0.415553
# review_useful                                         0.452379
# review_votes_count                                    0.469796
# review_length                                         0.260306
# business_review_count                                 0.080616
# user_cool                                             0.921460
# user_funny                                            0.929047
# user_useful                                           0.901122
# user_votes_count                                      0.919273
# user_review_count                                     0.613655
# user_fans                                             0.712853
# user_friends_count                                    0.305438
# user_years_elite_count                                0.352188
# user_compliments_cool                                 1.000000
# user_compliments_cool                                 1.000000
# user_compliments_cute                                 0.631012
# user_compliments_funny                                0.755798
# user_compliments_hot                                  0.952367
# user_compliments_list                                 0.804275
# user_compliments_more                                 0.921042
# user_compliments_note                                 0.881052
# user_compliments_photos                               0.754738
# user_compliments_plain                                0.947503
# user_compliments_profile                              0.824753
# user_compliments_writer                               0.972255
# positive_words_count                                  0.231500
# negative_words_count                                  0.136065
# positive_to_negative_words_count_ratio                0.072004
# negative_to_positive_words_count_ratio                0.004011
# neutral_words_count                                   0.260317
# neutral_words_count_over_review_length                0.051667
# positive_words_count_over_review_length              -0.048597
# negative_words_count_over_review_length              -0.012299
# friends_average_stars                                -0.081684
# user_average_stars                                   -0.031249
# business_stars                                        0.007230
# review_stars                                         -0.024261
#
#                                          user_compliments_cool  \
# review_cool                                           0.477984
# review_funny                                          0.415553
# review_useful                                         0.452379
# review_votes_count                                    0.469796
# review_length                                         0.260306
# business_review_count                                 0.080616
# user_cool                                             0.921460
# user_funny                                            0.929047
# user_useful                                           0.901122
# user_votes_count                                      0.919273
# user_review_count                                     0.613655
# user_fans                                             0.712853
# user_friends_count                                    0.305438
# user_years_elite_count                                0.352188
# user_compliments_cool                                 1.000000
# user_compliments_cool                                 1.000000
# user_compliments_cute                                 0.631012
# user_compliments_funny                                0.755798
# user_compliments_hot                                  0.952367
# user_compliments_list                                 0.804275
# user_compliments_more                                 0.921042
# user_compliments_note                                 0.881052
# user_compliments_photos                               0.754738
# user_compliments_plain                                0.947503
# user_compliments_profile                              0.824753
# user_compliments_writer                               0.972255
# positive_words_count                                  0.231500
# negative_words_count                                  0.136065
# positive_to_negative_words_count_ratio                0.072004
# negative_to_positive_words_count_ratio                0.004011
# neutral_words_count                                   0.260317
# neutral_words_count_over_review_length                0.051667
# positive_words_count_over_review_length              -0.048597
# negative_words_count_over_review_length              -0.012299
# friends_average_stars                                -0.081684
# user_average_stars                                   -0.031249
# business_stars                                        0.007230
# review_stars                                         -0.024261
#
#                                          user_compliments_cute  \
# review_cool                                           0.383362
# review_funny                                          0.320910
# review_useful                                         0.354063
# review_votes_count                                    0.369472
# review_length                                         0.172632
# business_review_count                                 0.070775
# user_cool                                             0.667963
# user_funny                                            0.662857
# user_useful                                           0.650150
# user_votes_count                                      0.662351
# user_review_count                                     0.452379
# user_fans                                             0.617142
# user_friends_count                                    0.241940
# user_years_elite_count                                0.299867
# user_compliments_cool                                 0.631012
# user_compliments_cool                                 0.631012
# user_compliments_cute                                 1.000000
# user_compliments_funny                                0.606250
# user_compliments_hot                                  0.774062
# user_compliments_list                                 0.852504
# user_compliments_more                                 0.702116
# user_compliments_note                                 0.603963
# user_compliments_photos                               0.787858
# user_compliments_plain                                0.619650
# user_compliments_profile                              0.768635
# user_compliments_writer                               0.611722
# positive_words_count                                  0.153121
# negative_words_count                                  0.079434
# positive_to_negative_words_count_ratio                0.078906
# negative_to_positive_words_count_ratio                0.004194
# neutral_words_count                                   0.172729
# neutral_words_count_over_review_length                0.034691
# positive_words_count_over_review_length              -0.032798
# negative_words_count_over_review_length              -0.007917
# friends_average_stars                                -0.067822
# user_average_stars                                    0.002955
# business_stars                                       -0.005245
# review_stars                                         -0.009787
#
#                                          user_compliments_funny      ...       \
# review_cool                                            0.458846      ...
# review_funny                                           0.425514      ...
# review_useful                                          0.440565      ...
# review_votes_count                                     0.461774      ...
# review_length                                          0.227607      ...
# business_review_count                                  0.060304      ...
# user_cool                                              0.780427      ...
# user_funny                                             0.807225      ...
# user_useful                                            0.774767      ...
# user_votes_count                                       0.788598      ...
# user_review_count                                      0.567605      ...
# user_fans                                              0.589908      ...
# user_friends_count                                     0.334122      ...
# user_years_elite_count                                 0.366383      ...
# user_compliments_cool                                  0.755798      ...
# user_compliments_cool                                  0.755798      ...
# user_compliments_cute                                  0.606250      ...
# user_compliments_funny                                 1.000000      ...
# user_compliments_hot                                   0.743012      ...
# user_compliments_list                                  0.634562      ...
# user_compliments_more                                  0.761317      ...
# user_compliments_note                                  0.884252      ...
# user_compliments_photos                                0.588489      ...
# user_compliments_plain                                 0.777282      ...
# user_compliments_profile                               0.645136      ...
# user_compliments_writer                                0.695206      ...
# positive_words_count                                   0.165699      ...
# negative_words_count                                   0.126601      ...
# positive_to_negative_words_count_ratio                 0.056823      ...
# negative_to_positive_words_count_ratio                 0.017478      ...
# neutral_words_count                                    0.228163      ...
# neutral_words_count_over_review_length                 0.059384      ...
# positive_words_count_over_review_length               -0.060149      ...
# negative_words_count_over_review_length               -0.005431      ...
# friends_average_stars                                 -0.092497      ...
# user_average_stars                                    -0.016826      ...
# business_stars                                        -0.011863      ...
# review_stars                                          -0.027014      ...
#
#                                          user_compliments_more  \
# review_cool                                           0.457428
# review_funny                                          0.399300
# review_useful                                         0.432569
# review_votes_count                                    0.449957
# review_length                                         0.238240
# business_review_count                                 0.065524
# user_cool                                             0.852654
# user_funny                                            0.870028
# user_useful                                           0.830431
# user_votes_count                                      0.851974
# user_review_count                                     0.543224
# user_fans                                             0.615624
# user_friends_count                                    0.287337
# user_years_elite_count                                0.321576
# user_compliments_cool                                 0.921042
# user_compliments_cool                                 0.921042
# user_compliments_cute                                 0.702116
# user_compliments_funny                                0.761317
# user_compliments_hot                                  0.887775
# user_compliments_list                                 0.863127
# user_compliments_more                                 1.000000
# user_compliments_note                                 0.883478
# user_compliments_photos                               0.847682
# user_compliments_plain                                0.857590
# user_compliments_profile                              0.947166
# user_compliments_writer                               0.943436
# positive_words_count                                  0.207821
# negative_words_count                                  0.124459
# positive_to_negative_words_count_ratio                0.066966
# negative_to_positive_words_count_ratio                0.005551
# neutral_words_count                                   0.238317
# neutral_words_count_over_review_length                0.049596
# positive_words_count_over_review_length              -0.047219
# negative_words_count_over_review_length              -0.010651
# friends_average_stars                                -0.083028
# user_average_stars                                   -0.032922
# business_stars                                       -0.007820
# review_stars                                         -0.029204
#
#                                          user_compliments_note  \
# review_cool                                           0.501344
# review_funny                                          0.437117
# review_useful                                         0.481452
# review_votes_count                                    0.495897
# review_length                                         0.248070
# business_review_count                                 0.050087
# user_cool                                             0.896483
# user_funny                                            0.897102
# user_useful                                           0.892265
# user_votes_count                                      0.898868
# user_review_count                                     0.641885
# user_fans                                             0.750927
# user_friends_count                                    0.362669
# user_years_elite_count                                0.406812
# user_compliments_cool                                 0.881052
# user_compliments_cool                                 0.881052
# user_compliments_cute                                 0.603963
# user_compliments_funny                                0.884252
# user_compliments_hot                                  0.806253
# user_compliments_list                                 0.714647
# user_compliments_more                                 0.883478
# user_compliments_note                                 1.000000
# user_compliments_photos                               0.648782
# user_compliments_plain                                0.912285
# user_compliments_profile                              0.752893
# user_compliments_writer                               0.842635
# positive_words_count                                  0.198128
# negative_words_count                                  0.127910
# positive_to_negative_words_count_ratio                0.078942
# negative_to_positive_words_count_ratio                0.012569
# neutral_words_count                                   0.248464
# neutral_words_count_over_review_length                0.064234
# positive_words_count_over_review_length              -0.061505
# negative_words_count_over_review_length              -0.013085
# friends_average_stars                                -0.101232
# user_average_stars                                   -0.019232
# business_stars                                        0.000678
# review_stars                                         -0.025679
#
#                                          user_compliments_photos  \
# review_cool                                             0.380861
# review_funny                                            0.327153
# review_useful                                           0.348418
# review_votes_count                                      0.368347
# review_length                                           0.164681
# business_review_count                                   0.047528
# user_cool                                               0.690787
# user_funny                                              0.700297
# user_useful                                             0.664161
# user_votes_count                                        0.685554
# user_review_count                                       0.403341
# user_fans                                               0.445215
# user_friends_count                                      0.182910
# user_years_elite_count                                  0.188650
# user_compliments_cool                                   0.754738
# user_compliments_cool                                   0.754738
# user_compliments_cute                                   0.787858
# user_compliments_funny                                  0.588489
# user_compliments_hot                                    0.824940
# user_compliments_list                                   0.855335
# user_compliments_more                                   0.847682
# user_compliments_note                                   0.648782
# user_compliments_photos                                 1.000000
# user_compliments_plain                                  0.681578
# user_compliments_profile                                0.911157
# user_compliments_writer                                 0.772153
# positive_words_count                                    0.147835
# negative_words_count                                    0.073665
# positive_to_negative_words_count_ratio                  0.058086
# negative_to_positive_words_count_ratio                 -0.003711
# neutral_words_count                                     0.164760
# neutral_words_count_over_review_length                  0.035420
# positive_words_count_over_review_length                -0.031376
# negative_words_count_over_review_length                -0.012363
# friends_average_stars                                  -0.058263
# user_average_stars                                     -0.011269
# business_stars                                         -0.001457
# review_stars                                           -0.012000
#
#                                          user_compliments_plain  \
# review_cool                                            0.479592
# review_funny                                           0.411991
# review_useful                                          0.455665
# review_votes_count                                     0.470525
# review_length                                          0.255720
# business_review_count                                  0.075320
# user_cool                                              0.924843
# user_funny                                             0.922697
# user_useful                                            0.920342
# user_votes_count                                       0.926512
# user_review_count                                      0.654710
# user_fans                                              0.808732
# user_friends_count                                     0.319437
# user_years_elite_count                                 0.367611
# user_compliments_cool                                  0.947503
# user_compliments_cool                                  0.947503
# user_compliments_cute                                  0.619650
# user_compliments_funny                                 0.777282
# user_compliments_hot                                   0.890937
# user_compliments_list                                  0.787124
# user_compliments_more                                  0.857590
# user_compliments_note                                  0.912285
# user_compliments_photos                                0.681578
# user_compliments_plain                                 1.000000
# user_compliments_profile                               0.759981
# user_compliments_writer                                0.909661
# positive_words_count                                   0.220319
# negative_words_count                                   0.131959
# positive_to_negative_words_count_ratio                 0.078227
# negative_to_positive_words_count_ratio                 0.007747
# neutral_words_count                                    0.255861
# neutral_words_count_over_review_length                 0.055535
# positive_words_count_over_review_length               -0.052739
# negative_words_count_over_review_length               -0.012198
# friends_average_stars                                 -0.090383
# user_average_stars                                    -0.019932
# business_stars                                         0.008870
# review_stars                                          -0.023983
#
#                                          user_compliments_profile  \
# review_cool                                              0.382522
# review_funny                                             0.328254
# review_useful                                            0.355578
# review_votes_count                                       0.372078
# review_length                                            0.185136
# business_review_count                                    0.052991
# user_cool                                                0.731807
# user_funny                                               0.746827
# user_useful                                              0.705655
# user_votes_count                                         0.728392
# user_review_count                                        0.422461
# user_fans                                                0.501927
# user_friends_count                                       0.199160
# user_years_elite_count                                   0.223506
# user_compliments_cool                                    0.824753
# user_compliments_cool                                    0.824753
# user_compliments_cute                                    0.768635
# user_compliments_funny                                   0.645136
# user_compliments_hot                                     0.838865
# user_compliments_list                                    0.914478
# user_compliments_more                                    0.947166
# user_compliments_note                                    0.752893
# user_compliments_photos                                  0.911157
# user_compliments_plain                                   0.759981
# user_compliments_profile                                 1.000000
# user_compliments_writer                                  0.869047
# positive_words_count                                     0.171568
# negative_words_count                                     0.092560
# positive_to_negative_words_count_ratio                   0.059462
# negative_to_positive_words_count_ratio                  -0.000841
# neutral_words_count                                      0.185062
# neutral_words_count_over_review_length                   0.034036
# positive_words_count_over_review_length                 -0.031287
# negative_words_count_over_review_length                 -0.009574
# friends_average_stars                                   -0.063073
# user_average_stars                                      -0.030236
# business_stars                                          -0.009853
# review_stars                                            -0.025593
#
#                                          user_compliments_writer  \
# review_cool                                             0.445645
# review_funny                                            0.388071
# review_useful                                           0.422212
# review_votes_count                                      0.438382
# review_length                                           0.268222
# business_review_count                                   0.082111
# user_cool                                               0.886480
# user_funny                                              0.900498
# user_useful                                             0.867690
# user_votes_count                                        0.886454
# user_review_count                                       0.592670
# user_fans                                               0.673640
# user_friends_count                                      0.284190
# user_years_elite_count                                  0.326035
# user_compliments_cool                                   0.972255
# user_compliments_cool                                   0.972255
# user_compliments_cute                                   0.611722
# user_compliments_funny                                  0.695206
# user_compliments_hot                                    0.919033
# user_compliments_list                                   0.834635
# user_compliments_more                                   0.943436
# user_compliments_note                                   0.842635
# user_compliments_photos                                 0.772153
# user_compliments_plain                                  0.909661
# user_compliments_profile                                0.869047
# user_compliments_writer                                 1.000000
# positive_words_count                                    0.240370
# negative_words_count                                    0.146990
# positive_to_negative_words_count_ratio                  0.065575
# negative_to_positive_words_count_ratio                  0.005764
# neutral_words_count                                     0.268151
# neutral_words_count_over_review_length                  0.049542
# positive_words_count_over_review_length                -0.047700
# negative_words_count_over_review_length                -0.009559
# friends_average_stars                                  -0.077644
# user_average_stars                                     -0.033080
# business_stars                                          0.003902
# review_stars                                           -0.026673
#
#                                          positive_words_count  \
# review_cool                                          0.304234
# review_funny                                         0.256926
# review_useful                                        0.327521
# review_votes_count                                   0.312286
# review_length                                        0.825695
# business_review_count                                0.085800
# user_cool                                            0.231146
# user_funny                                           0.230280
# user_useful                                          0.239385
# user_votes_count                                     0.235259
# ...
# user_compliments_list                                                  0.037450
# user_compliments_more                                                  0.049596
# user_compliments_note                                                  0.064234
# user_compliments_photos                                                0.035420
# user_compliments_plain                                                 0.055535
# user_compliments_profile                                               0.034036
# user_compliments_writer                                                0.049542
# positive_words_count                                                  -0.138036
# negative_words_count                                                  -0.052662
# positive_to_negative_words_count_ratio                                -0.058275
# negative_to_positive_words_count_ratio                                 0.031576
# neutral_words_count                                                    0.157619
# neutral_words_count_over_review_length                                 1.000000
# positive_words_count_over_review_length                               -0.886628
# negative_words_count_over_review_length                               -0.347434
# friends_average_stars                                                 -0.028971
# user_average_stars                                                    -0.021767
# business_stars                                                         0.004341
# review_stars                                                          -0.081850
#
#                                          positive_words_count_over_review_length  \
# review_cool                                                            -0.068285
# review_funny                                                           -0.075128
# review_useful                                                          -0.095917
# review_votes_count                                                     -0.084384
# review_length                                                          -0.168960
# business_review_count                                                  -0.052747
# user_cool                                                              -0.068037
# user_funny                                                             -0.067318
# user_useful                                                            -0.073609
# user_votes_count                                                       -0.070397
# user_review_count                                                      -0.085807
# user_fans                                                              -0.060839
# user_friends_count                                                     -0.075364
# user_years_elite_count                                                 -0.103413
# user_compliments_cool                                                  -0.048597
# user_compliments_cool                                                  -0.048597
# user_compliments_cute                                                  -0.032798
# user_compliments_funny                                                 -0.060149
# user_compliments_hot                                                   -0.044118
# user_compliments_list                                                  -0.035826
# user_compliments_more                                                  -0.047219
# user_compliments_note                                                  -0.061505
# user_compliments_photos                                                -0.031376
# user_compliments_plain                                                 -0.052739
# user_compliments_profile                                               -0.031287
# user_compliments_writer                                                -0.047700
# positive_words_count                                                    0.162555
# negative_words_count                                                   -0.168545
# positive_to_negative_words_count_ratio                                  0.454443
# negative_to_positive_words_count_ratio                                 -0.336446
# neutral_words_count                                                    -0.173506
# neutral_words_count_over_review_length                                 -0.886628
# positive_words_count_over_review_length                                 1.000000
# negative_words_count_over_review_length                                -0.125629
# friends_average_stars                                                   0.043539
# user_average_stars                                                      0.092415
# business_stars                                                          0.057999
# review_stars                                                            0.206898
#
#                                          negative_words_count_over_review_length  \
# review_cool                                                             0.001280
# review_funny                                                            0.047499
# review_useful                                                           0.016938
# review_votes_count                                                      0.021942
# review_length                                                           0.016315
# business_review_count                                                   0.040118
# user_cool                                                              -0.014514
# user_funny                                                             -0.007311
# user_useful                                                            -0.011807
# user_votes_count                                                       -0.011592
# user_review_count                                                       0.004714
# user_fans                                                              -0.009403
# user_friends_count                                                      0.020664
# user_years_elite_count                                                  0.005444
# user_compliments_cool                                                  -0.012299
# user_compliments_cool                                                  -0.012299
# user_compliments_cute                                                  -0.007917
# user_compliments_funny                                                 -0.005431
# user_compliments_hot                                                   -0.008533
# user_compliments_list                                                  -0.007694
# user_compliments_more                                                  -0.010651
# user_compliments_note                                                  -0.013085
# user_compliments_photos                                                -0.012363
# user_compliments_plain                                                 -0.012198
# user_compliments_profile                                               -0.009574
# user_compliments_writer                                                -0.009559
# positive_words_count                                                   -0.033484
# negative_words_count                                                    0.454698
# positive_to_negative_words_count_ratio                                 -0.474433
# negative_to_positive_words_count_ratio                                  0.708800
# neutral_words_count                                                     0.013680
# neutral_words_count_over_review_length                                 -0.347434
# positive_words_count_over_review_length                                -0.125629
# negative_words_count_over_review_length                                 1.000000
# friends_average_stars                                                  -0.026241
# user_average_stars                                                     -0.140682
# business_stars                                                         -0.126907
# review_stars                                                           -0.243917
#
#                                          friends_average_stars  \
# review_cool                                          -0.091877
# review_funny                                         -0.081851
# review_useful                                        -0.098597
# review_votes_count                                   -0.095349
# review_length                                        -0.069091
# business_review_count                                -0.045210
# user_cool                                            -0.109227
# user_funny                                           -0.106048
# user_useful                                          -0.118901
# user_votes_count                                     -0.112775
# user_review_count                                    -0.149040
# user_fans                                            -0.105497
# user_friends_count                                   -0.146398
# user_years_elite_count                               -0.126430
# user_compliments_cool                                -0.081684
# user_compliments_cool                                -0.081684
# user_compliments_cute                                -0.067822
# user_compliments_funny                               -0.092497
# user_compliments_hot                                 -0.076976
# user_compliments_list                                -0.073813
# user_compliments_more                                -0.083028
# user_compliments_note                                -0.101232
# user_compliments_photos                              -0.058263
# user_compliments_plain                               -0.090383
# user_compliments_profile                             -0.063073
# user_compliments_writer                              -0.077644
# positive_words_count                                 -0.047773
# negative_words_count                                 -0.065978
# positive_to_negative_words_count_ratio                0.002798
# negative_to_positive_words_count_ratio               -0.040531
# neutral_words_count                                  -0.069086
# neutral_words_count_over_review_length               -0.028971
# positive_words_count_over_review_length               0.043539
# negative_words_count_over_review_length              -0.026241
# friends_average_stars                                 1.000000
# user_average_stars                                    0.114914
# business_stars                                        0.034139
# review_stars                                          0.052303
#
#                                          user_average_stars  business_stars  \
# review_cool                                        0.015025        0.053364
# review_funny                                      -0.012673        0.004600
# review_useful                                     -0.007227        0.038117
# review_votes_count                                -0.001731        0.034515
# review_length                                     -0.048303        0.039988
# business_review_count                             -0.013404        0.055143
# user_cool                                         -0.014376        0.016211
# user_funny                                        -0.025143        0.008194
# user_useful                                       -0.020888        0.016897
# user_votes_count                                  -0.019898        0.014453
# user_review_count                                 -0.045239        0.006648
# user_fans                                          0.022053        0.034554
# user_friends_count                                 0.022297        0.024949
# user_years_elite_count                             0.004374        0.052868
# user_compliments_cool                             -0.031249        0.007230
# user_compliments_cool                             -0.031249        0.007230
# user_compliments_cute                              0.002955       -0.005245
# user_compliments_funny                            -0.016826       -0.011863
# user_compliments_hot                              -0.022258        0.003499
# user_compliments_list                             -0.016575        0.001407
# user_compliments_more                             -0.032922       -0.007820
# user_compliments_note                             -0.019232        0.000678
# user_compliments_photos                           -0.011269       -0.001457
# user_compliments_plain                            -0.019932        0.008870
# user_compliments_profile                          -0.030236       -0.009853
# user_compliments_writer                           -0.033080        0.003902
# positive_words_count                               0.007050        0.091646
# negative_words_count                              -0.127977       -0.087662
# positive_to_negative_words_count_ratio             0.135746        0.163766
# negative_to_positive_words_count_ratio            -0.179141       -0.155315
# neutral_words_count                               -0.048341        0.039899
# neutral_words_count_over_review_length            -0.021767        0.004341
# positive_words_count_over_review_length            0.092415        0.057999
# negative_words_count_over_review_length           -0.140682       -0.126907
# friends_average_stars                              0.114914        0.034139
# user_average_stars                                 1.000000        0.176973
# business_stars                                     0.176973        1.000000
# review_stars                                       0.439100        0.441851
#
#                                          review_stars
# review_cool                                  0.046922
# review_funny                                -0.023778
# review_useful                               -0.011676
# review_votes_count                           0.003824
# review_length                               -0.064584
# business_review_count                       -0.017451
# user_cool                                   -0.019483
# user_funny                                  -0.025592
# user_useful                                 -0.023706
# user_votes_count                            -0.022879
# user_review_count                           -0.036686
# user_fans                                    0.001371
# user_friends_count                           0.011285
# user_years_elite_count                       0.003875
# user_compliments_cool                       -0.024261
# user_compliments_cool                       -0.024261
# user_compliments_cute                       -0.009787
# user_compliments_funny                      -0.027014
# user_compliments_hot                        -0.023008
# user_compliments_list                       -0.016642
# user_compliments_more                       -0.029204
# user_compliments_note                       -0.025679
# user_compliments_photos                     -0.012000
# user_compliments_plain                      -0.023983
# user_compliments_profile                    -0.025593
# user_compliments_writer                     -0.026673
# positive_words_count                         0.080719
# negative_words_count                        -0.248268
# positive_to_negative_words_count_ratio       0.276092
# negative_to_positive_words_count_ratio      -0.349883
# neutral_words_count                         -0.065216
# neutral_words_count_over_review_length      -0.081850
# positive_words_count_over_review_length      0.206898
# negative_words_count_over_review_length     -0.243917
# friends_average_stars                        0.052303
# user_average_stars                           0.439100
# business_stars                               0.441851
# review_stars                                 1.000000
#
# [38 rows x 38 columns]

# %%
import plotly.plotly as py
import plotly.tools as tls
from plotly.graph_objs import *

def triangularize_symmetric_matrix(x, y, z):
    x_new = x[0:-1]
    y_new = y[-1:0:-1]
    tmp = np.empty(z.shape)
    tmp.fill(np.nan)
    for i in range(len(z)):
        tmp[i, 0 :i] = z[i, 0:i]
    tmp = np.flipud(tmp)
    z_new = tmp
    return (x_new, y_new, z_new)

# %%
py.sign_in('kevin11h', 'ilrcfqwrng')

(x, y, z) = triangularize_symmetric_matrix(corr_features,
                                           corr_features,
                                           Corr_df.as_matrix())

trace = Heatmap(z=z,
                x=x,
                y=y,
                zauto=False,
                zmax = 1,
                zmin = -1,
                colorscale=[[-1,'#3333CC'], [0, '#CC00CC'], [1, '#CC0000']],
                reversescale=True,
                colorbar=ColorBar(titleside='bottom',
                                  title='   %f'%-1))

data = Data([trace])

title = 'Feature Correlations of Yelp Reviews'
data_src_url = 'http://www.yelp.com/dataset_challenge'
annotation_text = 'Source and for more information: <a href="%s">Yelp Dataset Challenge</a>' % data_src_url

layout = Layout(title=title,
                autosize=False,
                height=500,
                width=600,
                annotations=Annotations([Annotation(text=annotation_text,
                                         xref='paper',
                                         yref='paper',
                                         xanchor='right',
                                         yanchor='bottom',
                                         x=.75,
                                         y=1)])
                )
axis_style = {'autotick':False,'showgrid':False,'showline':False}
layout.update(xaxis=XAxis(axis_style, tickangle=90))
layout.update(yaxis=YAxis(axis_style))

fig = Figure(data=data, layout=layout)

url = py.plot(fig, filename='yelp_feature_correlations', auto_open=False)
print url
py.iplot(fig, filename='yelp_feature_correlations')
# Out:
# https://plot.ly/~kevin11h/25

# %%
factors_affecting_review_stars_sorted_by_corr = sorted(zip(Corr_df.index, Corr_df['review_stars']), key = lambda factor_corr_pair : np.abs(factor_corr_pair[1]), reverse=True)
series_of_factors_affecting_review_stars_sorted_by_corr = Series(OrderedDict(factors_affecting_review_stars_sorted_by_corr))
series_of_factors_affecting_review_stars_sorted_by_corr
# Out:
# review_stars                               1.000000
# business_stars                             0.441851
# user_average_stars                         0.439100
# negative_to_positive_words_count_ratio    -0.349883
# positive_to_negative_words_count_ratio     0.276092
# negative_words_count                      -0.248268
# negative_words_count_over_review_length   -0.243917
# positive_words_count_over_review_length    0.206898
# neutral_words_count_over_review_length    -0.081850
# positive_words_count                       0.080719
# neutral_words_count                       -0.065216
# review_length                             -0.064584
# friends_average_stars                      0.052303
# review_cool                                0.046922
# user_review_count                         -0.036686
# user_compliments_more                     -0.029204
# user_compliments_funny                    -0.027014
# user_compliments_writer                   -0.026673
# user_compliments_note                     -0.025679
# user_compliments_profile                  -0.025593
# user_funny                                -0.025592
# user_compliments_cool                     -0.024261
# user_compliments_plain                    -0.023983
# review_funny                              -0.023778
# user_useful                               -0.023706
# user_compliments_hot                      -0.023008
# user_votes_count                          -0.022879
# user_cool                                 -0.019483
# business_review_count                     -0.017451
# user_compliments_list                     -0.016642
# user_compliments_photos                   -0.012000
# review_useful                             -0.011676
# user_friends_count                         0.011285
# user_compliments_cute                     -0.009787
# user_years_elite_count                     0.003875
# review_votes_count                         0.003824
# user_fans                                  0.001371
# dtype: float64

# %% [markdown]
# So positive and negative words per review length and ratio turn out to have a good correlation of review stars

# %%
df_with_refeature_engineered.positive_words_count_over_review_length.describe()
# Out:
# count    36802.000000
# mean         0.018872
# std          0.014927
# min          0.000000
# 25%          0.010204
# 50%          0.016760
# 75%          0.024691
# max          0.250000
# Name: positive_words_count_over_review_length, dtype: float64

# %%
df_with_refeature_engineered['negative_words_count_over_review_length'].describe()
# Out:
# count    36802.000000
# mean         0.005040
# std          0.007362
# min          0.000000
# 25%          0.000000
# 50%          0.003003
# 75%          0.007673
# max          0.333333
# Name: negative_words_count_over_review_length, dtype: float64

# %% [markdown]
# Let's overplay the negativity of Yelp reviews since our classifier often confuses 1,2,3 star reviews with 4 stars

# %%
def multiply_negative_words(by=1):
    def apply_func(document=''):
        negative_words = filter(lambda s : s in NEGATIVE_WORDS, document.split())
        return document + ' ' + ' '.join(negative_words * (by-1))
    return apply_func

# %%
negativity_factor = 10
m  = multiply_negative_words(negativity_factor)
df_with_refeature_engineered_and_preprocessed_review_text = TURBO_DF[initial_features]
df_with_refeature_engineered_and_preprocessed_review_text['overly_negative_review_text'] = TURBO_DF.review_text.apply(m)
# %time df_with_refeature_engineered_and_preprocessed_review_text.overly_negative_review_text = df_with_refeature_engineered_and_preprocessed_review_text.overly_negative_review_text.apply(lowercase_remove_punctuation_and_numbers_and_tokenize_and_filter_more_stopwords_and_stem_and_restring)

for idx in range(5):
    print df_with_refeature_engineered_and_preprocessed_review_text.overly_negative_review_text[idx]
    print
# Out:
# -c:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/kevin/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# CPU times: user 1min 41s, sys: 228 ms, total: 1min 41s
# Wall time: 1min 41s
# awesom decor great servic hidden gem scottsdal delici uniqu menu lamb fondu great trout salad chicken interest bread basket assort muffin bread divers dessert menu bit chocol great place restaur scottsdal
#
# defalco locat thoma eaten italian deli valley place rival qualiti food excel staff custom continu return highli recommend purista chp chees steak margerit pizza tim special pizza soup italian item beat wine select fantast toni defalco owner singl wine put bottl shelv fantast wine number region place eat time week year healthi delici make call order ahead place busi defalco true desert classic year recip friendliest staff dedic excel desert desert desert desert desert desert desert desert desert
#
# defalco locat thoma eaten italian deli valley place rival qualiti food excel staff custom continu return highli recommend purista chp chees steak margerit pizza tim special pizza soup italian item beat wine select fantast toni defalco owner singl wine put bottl shelv fantast wine number region place eat time week year healthi delici make call order ahead place busi defalco true desert classic year recip friendliest staff dedic excel desert desert desert desert desert desert desert desert desert
#
# defalco locat thoma eaten italian deli valley place rival qualiti food excel staff custom continu return highli recommend purista chp chees steak margerit pizza tim special pizza soup italian item beat wine select fantast toni defalco owner singl wine put bottl shelv fantast wine number region place eat time week year healthi delici make call order ahead place busi defalco true desert classic year recip friendliest staff dedic excel desert desert desert desert desert desert desert desert desert
#
# defalco slowli perfect pizza recip coupl year crust favorit valley highli recommend pizza sweet italian sausag heavenli slowli slowli slowli slowli slowli slowli slowli slowli slowli

# %%
train_X, test_X, train_y, test_y = train_test_split(df_with_refeature_engineered_and_preprocessed_review_text.overly_negative_review_text,
                                                    df_with_refeature_engineered_and_preprocessed_review_text.review_stars,
                                                    test_size=TEST_SIZE,
                                                    random_state=42)

# %%
# %time clf = Multinomial_NB_Classifier().train(class_labels=train_y, documents=train_X)
# Out:
# CPU times: user 2min 33s, sys: 5.94 s, total: 2min 39s
# Wall time: 2min 39s

# %%
# %time overly_negative_multinomial_nb_prediction = clf.predict(test_X)
# Out:
# CPU times: user 5.32 s, sys: 36 ms, total: 5.36 s
# Wall time: 5.33 s

# %%
overly_negative_multinomial_confusion_matrix = confusion_matrix(test_y, overly_negative_multinomial_nb_prediction)
plot_confusion_matrix(overly_negative_multinomial_confusion_matrix,
                      'My Multinomial Naive Bayes Confusion Matrix with Overly Negative Reviews', savefilename='MyMultinomialOverlyNegativeCM.png')

# %%
print_classifier_performance_metrics('Overly Negative Multinomial Naive Bayes', overly_negative_multinomial_nb_prediction)
# Out:
# MODEL: Overly Negative Multinomial Naive Bayes
#
# Precision: 0.613245360537
# Recall: 0.613781398506
# F1: 0.593834310351
# Accuracy: 0.613781398506
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.76      0.39      0.52       884
#      2 star       0.62      0.15      0.25       810
#      3 star       0.53      0.28      0.37      1965
#      4 star       0.53      0.63      0.58      4897
#      5 star       0.68      0.80      0.73      6174
#
# avg / total       0.61      0.61      0.59     14730
#
#
# Precision variance: 0.040448
#
# Recall variance: 0.273579

# %% [markdown]
# Unfortunately that wasn't much of an improvement, so let's try oversampling the minority 1,2, and 3 star reviews instead. <br />
# Since 1, 2, and 3 star reviews often get confused with 4 star reviews, let's train more 1, 2, and 3 star reviews to match the amount of 4 star reviews trained.

# %% [markdown]
# ### Oversampling Minority Classes

# %%
TEST_SIZE = 0.40
train_X, test_X, train_y, test_y = train_test_split(df_with_initial_features_and_preprocessed_review_text.review_text,
                                                    df_with_initial_features_and_preprocessed_review_text.review_stars,
                                                    test_size=TEST_SIZE,
                                                    random_state=42)

ONE_STAR_LABEL = 1
TWO_STAR_LABEL = 2
THREE_STAR_LABEL = 3
FOUR_STAR_LABEL = 4

one_star_reviews = train_X[train_y == ONE_STAR_LABEL]
two_star_reviews = train_X[train_y == TWO_STAR_LABEL]
three_star_reviews = train_X[train_y == THREE_STAR_LABEL]
four_star_reviews = train_X[train_y == FOUR_STAR_LABEL]

one_star_labels = train_y[train_y == ONE_STAR_LABEL]
two_star_labels = train_y[train_y == TWO_STAR_LABEL]
three_star_labels = train_y[train_y == THREE_STAR_LABEL]

difference_btw_number_of_4_and_1_stars = len(four_star_reviews) - len(one_star_reviews)
difference_btw_number_of_4_and_2_stars = len(four_star_reviews) - len(two_star_reviews)
difference_btw_number_of_4_and_3_stars = len(four_star_reviews) - len(three_star_reviews)

assert (np.array([difference_btw_number_of_4_and_1_stars,
                 difference_btw_number_of_4_and_2_stars,
                 difference_btw_number_of_4_and_3_stars]) > 0).all()

q1 = difference_btw_number_of_4_and_1_stars/len(one_star_reviews)
r1 = difference_btw_number_of_4_and_1_stars - len(one_star_reviews) * q1
q2 = difference_btw_number_of_4_and_2_stars/len(two_star_reviews)
r2 = difference_btw_number_of_4_and_2_stars - len(two_star_reviews) * q2
q3 = difference_btw_number_of_4_and_3_stars/len(three_star_reviews)
r3 = difference_btw_number_of_4_and_3_stars - len(three_star_reviews) * q3

train_X = np.vstack([np.reshape(train_X, (len(train_X), 1)),
                     np.tile(one_star_reviews, (1, q1)).T,
                     np.reshape(one_star_reviews[:r1], (r1, 1)),
                     np.tile(two_star_reviews, (1, q2)).T,
                     np.reshape(two_star_reviews[:r2], (r2, 1)),
                     np.tile(three_star_reviews, (1, q3)).T,
                     np.reshape(three_star_reviews[:r3], (r3, 1))])[:,0]

train_y = np.vstack([np.reshape(train_y, (len(train_y), 1)),
                     np.tile(one_star_labels, (1, q1)).T,
                     np.reshape(one_star_labels[:r1], (r1, 1)),
                     np.tile(two_star_labels, (1, q2)).T,
                     np.reshape(two_star_labels[:r2], (r2, 1)),
                     np.tile(three_star_labels, (1, q3)).T,
                     np.reshape(three_star_labels[:r3], (r3, 1))])[:,0]

# %%
# %time clf = Multinomial_NB_Classifier().train(class_labels=train_y, documents=train_X)
# Out:
# CPU times: user 5min 1s, sys: 232 ms, total: 5min 2s
# Wall time: 5min 2s

# %%
# %time oversampling_multinomial_nb_prediction = clf.predict(test_X)
# Out:
# CPU times: user 5.34 s, sys: 28 ms, total: 5.37 s
# Wall time: 5.3 s

# %%
oversampling_multinomial_confusion_matrix = confusion_matrix(test_y, oversampling_multinomial_nb_prediction)
print make_confusion_matrix_relative(oversampling_multinomial_confusion_matrix)
plot_confusion_matrix(oversampling_multinomial_confusion_matrix,
                      'My Multinomial Naive Bayes Confusion Matrix with Oversampling for Minority Classes', savefilename='MyMultinomialOversamplingCM.png')
# Out:
# [[ 0.66742081  0.18778281  0.08936652  0.03733032  0.01809955]
#  [ 0.19012346  0.42345679  0.20246914  0.12222222  0.0617284 ]
#  [ 0.06717557  0.09720102  0.49720102  0.2351145   0.10330789]
#  [ 0.030631    0.04390443  0.16806208  0.51745967  0.23994282]
#  [ 0.03320376  0.02008422  0.06122449  0.1776806   0.70780693]]

# %%
print_classifier_performance_metrics('Multinomial Naive Bayes Trained on Oversampling', oversampling_multinomial_nb_prediction)
# Out:
# MODEL: Multinomial Naive Bayes Trained on Oversampling
#
# Precision: 0.615186609739
# Recall: 0.598370672098
# F1: 0.603601514259
# Accuracy: 0.598370672098
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.48      0.67      0.56       884
#      2 star       0.33      0.42      0.37       810
#      3 star       0.40      0.50      0.45      1965
#      4 star       0.60      0.52      0.56      4897
#      5 star       0.75      0.71      0.73      6174
#
# avg / total       0.62      0.60      0.60     14730
#
#
# Precision variance: 0.111033
#
# Recall variance: 0.057748

# %% [markdown]
# ### Oversampling with Bigram Multinomial Naive Bayes

# %%
oversampling_bigram_multinomial_feature_matrix_train = bigram_vectorizer.fit_transform(train_X)
oversampling_bigram_multinomial_feature_matrix_test = bigram_vectorizer.transform(test_X)
oversampling_bigram_multinomial_nb_classifier = MultinomialNB().fit(oversampling_bigram_multinomial_feature_matrix_train, train_y)
oversampling_bigram_multinomial_nb_prediction = oversampling_bigram_multinomial_nb_classifier.predict(oversampling_bigram_multinomial_feature_matrix_test)

# %%
oversampling_bigram_multinomial_confusion_matrix = confusion_matrix(test_y, oversampling_bigram_multinomial_nb_prediction)
print make_confusion_matrix_relative(oversampling_bigram_multinomial_confusion_matrix)
plot_confusion_matrix(oversampling_bigram_multinomial_confusion_matrix,
                      'Bigram Multinomial Naive Bayes with Oversampling \n for Minority Classes Confusion Matrix', savefilename='BigramMultinomialOversamplingCM.png')
# Out:
# [[ 0.54072398  0.13348416  0.11764706  0.10746606  0.10067873]
#  [ 0.12222222  0.33950617  0.18518519  0.22345679  0.12962963]
#  [ 0.02697201  0.04173028  0.49058524  0.29618321  0.14452926]
#  [ 0.01204819  0.02062487  0.08352052  0.65448234  0.22932408]
#  [ 0.01182378  0.00988014  0.03498542  0.1553288   0.78798186]]

# %%
print_classifier_performance_metrics('Bigram Naive Bayes Trained on Oversampling', oversampling_bigram_multinomial_nb_prediction)
# Out:
# MODEL: Bigram Naive Bayes Trained on Oversampling
#
# Precision: 0.65869352317
# Recall: 0.664426340801
# F1: 0.660788487914
# Accuracy: 0.664426340801
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.63      0.54      0.58       884
#      2 star       0.43      0.34      0.38       810
#      3 star       0.52      0.49      0.51      1965
#      4 star       0.64      0.65      0.65      4897
#      5 star       0.75      0.79      0.77      6174
#
# avg / total       0.66      0.66      0.66     14730
#
#
# Precision variance: 0.059520
#
# Recall variance: 0.114675

# %% [markdown]
# It seems that oversampling decreases the accuracy of our predictions as whole, but it also decreases the recall variance which is what we're looking for

# %% [markdown]
# ### Multiclass Logistic Regression Model

# %% [markdown]
# Transform Yelp Reviews into feature vectors

# %%
TEST_SIZE = 0.40
train_X, test_X, train_y, test_y = train_test_split(df_with_initial_features_and_preprocessed_review_text.review_text,
                                                    df_with_initial_features_and_preprocessed_review_text.review_stars,
                                                    test_size=TEST_SIZE,
                                                    random_state=42)

# %%
BIGRAM_RANGE = (2, 2)
v = CountVectorizer(analyzer = "word",
                    tokenizer = None,
                    preprocessor = None,
                    ngram_range = BIGRAM_RANGE,
                    strip_accents = 'unicode')

# %%
logistic_feature_matrix_train = v.fit_transform(train_X)
logistic_feature_matrix_test = v.transform(test_X)

logistic_feature_matrix_train, logistic_feature_matrix_test
# Out:
# (<22094x438111 sparse matrix of type '<type 'numpy.int64'>'
#  	with 1010572 stored elements in Compressed Sparse Row format>,
#  <14730x438111 sparse matrix of type '<type 'numpy.int64'>'
#  	with 483725 stored elements in Compressed Sparse Row format>)

# %%
n_positive_words_series = df_with_initial_features_and_preprocessed_review_text.review_text.apply(count_number_of_positive_words)
n_negative_words_series = df_with_initial_features_and_preprocessed_review_text.review_text.apply(count_number_of_negative_words)
negative_to_positive_words_ratio_vector = 1000*((n_negative_words_series + 1.0)/ (n_positive_words_series+1.0)).values
negative_to_positive_words_ratio_vector = np.reshape(negative_to_positive_words_ratio_vector, (len(negative_to_positive_words_ratio_vector), 1))

# %%
from scipy.sparse import hstack
n_training_samples = (logistic_feature_matrix_train.shape[0])
logistic_feature_matrix_train = hstack([logistic_feature_matrix_train, negative_to_positive_words_ratio_vector[:n_training_samples]])
logistic_feature_matrix_test  = hstack([logistic_feature_matrix_test, negative_to_positive_words_ratio_vector[n_training_samples:]])

logistic_feature_matrix_train, logistic_feature_matrix_test
# Out:
# (<22094x438112 sparse matrix of type '<type 'numpy.float64'>'
#  	with 1032666 stored elements in COOrdinate format>,
#  <14730x438112 sparse matrix of type '<type 'numpy.float64'>'
#  	with 498455 stored elements in COOrdinate format>)

# %% [markdown]
# Train Logistic Regression

# %%
logistic_clf = LogisticRegression(C=1e3)
# %time logistic_clf.fit(logistic_feature_matrix_train, train_y)
# Out:
# CPU times: user 40.4 s, sys: 20 ms, total: 40.4 s
# Wall time: 40.9 s
# LogisticRegression(C=1000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, penalty='l2',
#           random_state=None, tol=0.0001)

# %%
# %time logreg_pred = logistic_clf.predict(logistic_feature_matrix_test)
# Out:
# CPU times: user 64 ms, sys: 0 ns, total: 64 ms
# Wall time: 63.1 ms

# %% [markdown]
# Visualize results in a confusion matrix

# %%
logreg_confusion_matrix = confusion_matrix(test_y, logreg_pred)
plot_confusion_matrix(logreg_confusion_matrix, 'Logistic Regression Confusion Matrix', savefilename='LogRegCM.png')

# %%
print_classifier_performance_metrics('Logistic Regression', logreg_pred)
# Out:
# MODEL: Logistic Regression
#
# Precision: 0.680634188102
# Recall: 0.669585879158
# F1: 0.653038494908
# Accuracy: 0.669585879158
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.74      0.43      0.54       884
#      2 star       0.81      0.26      0.39       810
#      3 star       0.71      0.41      0.52      1965
#      4 star       0.67      0.63      0.65      4897
#      5 star       0.66      0.87      0.75      6174
#
# avg / total       0.68      0.67      0.65     14730
#
#
# Precision variance: 0.014668
#
# Recall variance: 0.223353

# %% [markdown]
# ### Retraining Bigram Multinomial Naive Bayes with Oversampling with different Test Sizes

# %%
TEST_SIZE = 0.20
train_X, test_X, train_y, test_y = train_test_split(df_with_initial_features_and_preprocessed_review_text.review_text,
                                                    df_with_initial_features_and_preprocessed_review_text.review_stars,
                                                    test_size=TEST_SIZE,
                                                    random_state=42)

ONE_STAR_LABEL = 1
TWO_STAR_LABEL = 2
THREE_STAR_LABEL = 3
FOUR_STAR_LABEL = 4

one_star_reviews = train_X[train_y == ONE_STAR_LABEL]
two_star_reviews = train_X[train_y == TWO_STAR_LABEL]
three_star_reviews = train_X[train_y == THREE_STAR_LABEL]
four_star_reviews = train_X[train_y == FOUR_STAR_LABEL]

one_star_labels = train_y[train_y == ONE_STAR_LABEL]
two_star_labels = train_y[train_y == TWO_STAR_LABEL]
three_star_labels = train_y[train_y == THREE_STAR_LABEL]

difference_btw_number_of_4_and_1_stars = len(four_star_reviews) - len(one_star_reviews)
difference_btw_number_of_4_and_2_stars = len(four_star_reviews) - len(two_star_reviews)
difference_btw_number_of_4_and_3_stars = len(four_star_reviews) - len(three_star_reviews)

assert (np.array([difference_btw_number_of_4_and_1_stars,
                 difference_btw_number_of_4_and_2_stars,
                 difference_btw_number_of_4_and_3_stars]) > 0).all()

q1 = difference_btw_number_of_4_and_1_stars/len(one_star_reviews)
r1 = difference_btw_number_of_4_and_1_stars - len(one_star_reviews) * q1
q2 = difference_btw_number_of_4_and_2_stars/len(two_star_reviews)
r2 = difference_btw_number_of_4_and_2_stars - len(two_star_reviews) * q2
q3 = difference_btw_number_of_4_and_3_stars/len(three_star_reviews)
r3 = difference_btw_number_of_4_and_3_stars - len(three_star_reviews) * q3

train_X = np.vstack([np.reshape(train_X, (len(train_X), 1)),
                     np.tile(one_star_reviews, (1, q1)).T,
                     np.reshape(one_star_reviews[:r1], (r1, 1)),
                     np.tile(two_star_reviews, (1, q2)).T,
                     np.reshape(two_star_reviews[:r2], (r2, 1)),
                     np.tile(three_star_reviews, (1, q3)).T,
                     np.reshape(three_star_reviews[:r3], (r3, 1))])[:,0]

train_y = np.vstack([np.reshape(train_y, (len(train_y), 1)),
                     np.tile(one_star_labels, (1, q1)).T,
                     np.reshape(one_star_labels[:r1], (r1, 1)),
                     np.tile(two_star_labels, (1, q2)).T,
                     np.reshape(two_star_labels[:r2], (r2, 1)),
                     np.tile(three_star_labels, (1, q3)).T,
                     np.reshape(three_star_labels[:r3], (r3, 1))])[:,0]

# %%
twenty_oversampling_bigram_multinomial_feature_matrix_train = bigram_vectorizer.fit_transform(train_X)
twenty_oversampling_bigram_multinomial_feature_matrix_test = bigram_vectorizer.transform(test_X)
twenty_oversampling_bigram_multinomial_nb_classifier = MultinomialNB().fit(twenty_oversampling_bigram_multinomial_feature_matrix_train, train_y)
twenty_oversampling_bigram_multinomial_nb_prediction = twenty_oversampling_bigram_multinomial_nb_classifier.predict(twenty_oversampling_bigram_multinomial_feature_matrix_test)

# %%
twenty_oversampling_bigram_multinomial_confusion_matrix = confusion_matrix(test_y, twenty_oversampling_bigram_multinomial_nb_prediction)
print make_confusion_matrix_relative(twenty_oversampling_bigram_multinomial_confusion_matrix)
plot_confusion_matrix(twenty_oversampling_bigram_multinomial_confusion_matrix,
                      'Bigram Multinomial Naive Bayes with Oversampling \n for Minority Classes and 20% Testing Confusion Matrix',
                      savefilename='TwentyBigramMultinomialOversamplingCM.png')
# Out:
# [[ 0.53229399  0.13808463  0.12026726  0.09576837  0.11358575]
#  [ 0.11508951  0.39897698  0.17391304  0.19948849  0.11253197]
#  [ 0.02224469  0.04246714  0.51668352  0.29929221  0.11931244]
#  [ 0.01485347  0.02087515  0.08069049  0.67884384  0.20473705]
#  [ 0.01083744  0.01050903  0.03546798  0.14581281  0.79737274]]

# %%
print_classifier_performance_metrics('Bigram Multinomial Naive Bayes Trained on Oversampling and 20% Test Data',
                                     twenty_oversampling_bigram_multinomial_nb_prediction)
# Out:
# MODEL: Bigram Multinomial Naive Bayes Trained on Oversampling and 20% Test Data
#
# Precision: 0.678358918493
# Recall: 0.682281059063
# F1: 0.679778537232
# Accuracy: 0.682281059063
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.64      0.53      0.58       449
#      2 star       0.45      0.40      0.42       391
#      3 star       0.54      0.52      0.53       989
#      4 star       0.66      0.68      0.67      2491
#      5 star       0.77      0.80      0.78      3045
#
# avg / total       0.68      0.68      0.68      7365
#
#
# Precision variance: 0.058216
#
# Recall variance: 0.095958

# %%
TEST_SIZE = 0.60
train_X, test_X, train_y, test_y = train_test_split(df_with_initial_features_and_preprocessed_review_text.review_text,
                                                    df_with_initial_features_and_preprocessed_review_text.review_stars,
                                                    test_size=TEST_SIZE,
                                                    random_state=42)

ONE_STAR_LABEL = 1
TWO_STAR_LABEL = 2
THREE_STAR_LABEL = 3
FOUR_STAR_LABEL = 4

one_star_reviews = train_X[train_y == ONE_STAR_LABEL]
two_star_reviews = train_X[train_y == TWO_STAR_LABEL]
three_star_reviews = train_X[train_y == THREE_STAR_LABEL]
four_star_reviews = train_X[train_y == FOUR_STAR_LABEL]

one_star_labels = train_y[train_y == ONE_STAR_LABEL]
two_star_labels = train_y[train_y == TWO_STAR_LABEL]
three_star_labels = train_y[train_y == THREE_STAR_LABEL]

difference_btw_number_of_4_and_1_stars = len(four_star_reviews) - len(one_star_reviews)
difference_btw_number_of_4_and_2_stars = len(four_star_reviews) - len(two_star_reviews)
difference_btw_number_of_4_and_3_stars = len(four_star_reviews) - len(three_star_reviews)

assert (np.array([difference_btw_number_of_4_and_1_stars,
                 difference_btw_number_of_4_and_2_stars,
                 difference_btw_number_of_4_and_3_stars]) > 0).all()

q1 = difference_btw_number_of_4_and_1_stars/len(one_star_reviews)
r1 = difference_btw_number_of_4_and_1_stars - len(one_star_reviews) * q1
q2 = difference_btw_number_of_4_and_2_stars/len(two_star_reviews)
r2 = difference_btw_number_of_4_and_2_stars - len(two_star_reviews) * q2
q3 = difference_btw_number_of_4_and_3_stars/len(three_star_reviews)
r3 = difference_btw_number_of_4_and_3_stars - len(three_star_reviews) * q3

train_X = np.vstack([np.reshape(train_X, (len(train_X), 1)),
                     np.tile(one_star_reviews, (1, q1)).T,
                     np.reshape(one_star_reviews[:r1], (r1, 1)),
                     np.tile(two_star_reviews, (1, q2)).T,
                     np.reshape(two_star_reviews[:r2], (r2, 1)),
                     np.tile(three_star_reviews, (1, q3)).T,
                     np.reshape(three_star_reviews[:r3], (r3, 1))])[:,0]

train_y = np.vstack([np.reshape(train_y, (len(train_y), 1)),
                     np.tile(one_star_labels, (1, q1)).T,
                     np.reshape(one_star_labels[:r1], (r1, 1)),
                     np.tile(two_star_labels, (1, q2)).T,
                     np.reshape(two_star_labels[:r2], (r2, 1)),
                     np.tile(three_star_labels, (1, q3)).T,
                     np.reshape(three_star_labels[:r3], (r3, 1))])[:,0]

# %%
sixty_oversampling_bigram_multinomial_feature_matrix_train = bigram_vectorizer.fit_transform(train_X)
sixty_oversampling_bigram_multinomial_feature_matrix_test = bigram_vectorizer.transform(test_X)
sixty_oversampling_bigram_multinomial_nb_classifier = MultinomialNB().fit(sixty_oversampling_bigram_multinomial_feature_matrix_train, train_y)
sixty_oversampling_bigram_multinomial_nb_prediction = sixty_oversampling_bigram_multinomial_nb_classifier.predict(sixty_oversampling_bigram_multinomial_feature_matrix_test)

# %%
sixty_oversampling_bigram_multinomial_confusion_matrix = confusion_matrix(test_y, sixty_oversampling_bigram_multinomial_nb_prediction)
print make_confusion_matrix_relative(sixty_oversampling_bigram_multinomial_confusion_matrix)
plot_confusion_matrix(sixty_oversampling_bigram_multinomial_confusion_matrix,
                      'Bigram Multinomial Naive Bayes with Oversampling \n for Minority Classes and 60% Testing Confusion Matrix',
                      savefilename='SixtyBigramMultinomialOversamplingCM.png')
# Out:
# [[ 0.49513109  0.14981273  0.13558052  0.11835206  0.1011236 ]
#  [ 0.12073272  0.30474604  0.194005    0.24646128  0.13405495]
#  [ 0.03899627  0.04408274  0.44828756  0.32078671  0.14784673]
#  [ 0.01020686  0.02299946  0.09608057  0.62221013  0.24850299]
#  [ 0.0131721   0.01381991  0.04469877  0.17253293  0.75577629]]

# %%
print_classifier_performance_metrics('Bigram Multinomial Naive Bayes Trained on Oversampling and 60% Test Data',
                                     sixty_oversampling_bigram_multinomial_nb_prediction)
# Out:
# MODEL: Bigram Multinomial Naive Bayes Trained on Oversampling and 60% Test Data
#
# Precision: 0.625397116228
# Recall: 0.630052047975
# F1: 0.627165355421
# Accuracy: 0.630052047975
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.59      0.50      0.54      1335
#      2 star       0.37      0.30      0.33      1201
#      3 star       0.46      0.45      0.46      2949
#      4 star       0.60      0.62      0.61      7348
#      5 star       0.73      0.76      0.74      9262
#
# avg / total       0.63      0.63      0.63     22095
#
#
# Precision variance: 0.078357
# Recall variance: 0.117996

# %%
TEST_SIZE = 0.80
train_X, test_X, train_y, test_y = train_test_split(df_with_initial_features_and_preprocessed_review_text.review_text,
                                                    df_with_initial_features_and_preprocessed_review_text.review_stars,
                                                    test_size=TEST_SIZE,
                                                    random_state=42)

ONE_STAR_LABEL = 1
TWO_STAR_LABEL = 2
THREE_STAR_LABEL = 3
FOUR_STAR_LABEL = 4

one_star_reviews = train_X[train_y == ONE_STAR_LABEL]
two_star_reviews = train_X[train_y == TWO_STAR_LABEL]
three_star_reviews = train_X[train_y == THREE_STAR_LABEL]
four_star_reviews = train_X[train_y == FOUR_STAR_LABEL]

one_star_labels = train_y[train_y == ONE_STAR_LABEL]
two_star_labels = train_y[train_y == TWO_STAR_LABEL]
three_star_labels = train_y[train_y == THREE_STAR_LABEL]

difference_btw_number_of_4_and_1_stars = len(four_star_reviews) - len(one_star_reviews)
difference_btw_number_of_4_and_2_stars = len(four_star_reviews) - len(two_star_reviews)
difference_btw_number_of_4_and_3_stars = len(four_star_reviews) - len(three_star_reviews)

assert (np.array([difference_btw_number_of_4_and_1_stars,
                 difference_btw_number_of_4_and_2_stars,
                 difference_btw_number_of_4_and_3_stars]) > 0).all()

q1 = difference_btw_number_of_4_and_1_stars/len(one_star_reviews)
r1 = difference_btw_number_of_4_and_1_stars - len(one_star_reviews) * q1
q2 = difference_btw_number_of_4_and_2_stars/len(two_star_reviews)
r2 = difference_btw_number_of_4_and_2_stars - len(two_star_reviews) * q2
q3 = difference_btw_number_of_4_and_3_stars/len(three_star_reviews)
r3 = difference_btw_number_of_4_and_3_stars - len(three_star_reviews) * q3

train_X = np.vstack([np.reshape(train_X, (len(train_X), 1)),
                     np.tile(one_star_reviews, (1, q1)).T,
                     np.reshape(one_star_reviews[:r1], (r1, 1)),
                     np.tile(two_star_reviews, (1, q2)).T,
                     np.reshape(two_star_reviews[:r2], (r2, 1)),
                     np.tile(three_star_reviews, (1, q3)).T,
                     np.reshape(three_star_reviews[:r3], (r3, 1))])[:,0]

train_y = np.vstack([np.reshape(train_y, (len(train_y), 1)),
                     np.tile(one_star_labels, (1, q1)).T,
                     np.reshape(one_star_labels[:r1], (r1, 1)),
                     np.tile(two_star_labels, (1, q2)).T,
                     np.reshape(two_star_labels[:r2], (r2, 1)),
                     np.tile(three_star_labels, (1, q3)).T,
                     np.reshape(three_star_labels[:r3], (r3, 1))])[:,0]

# %%
eighty_oversampling_bigram_multinomial_feature_matrix_train = bigram_vectorizer.fit_transform(train_X)
eighty_oversampling_bigram_multinomial_feature_matrix_test = bigram_vectorizer.transform(test_X)
eighty_oversampling_bigram_multinomial_nb_classifier = MultinomialNB().fit(eighty_oversampling_bigram_multinomial_feature_matrix_train, train_y)
eighty_oversampling_bigram_multinomial_nb_prediction = eighty_oversampling_bigram_multinomial_nb_classifier.predict(eighty_oversampling_bigram_multinomial_feature_matrix_test)

# %%
eighty_oversampling_bigram_multinomial_confusion_matrix = confusion_matrix(test_y, eighty_oversampling_bigram_multinomial_nb_prediction)
print make_confusion_matrix_relative(eighty_oversampling_bigram_multinomial_confusion_matrix)
plot_confusion_matrix(eighty_oversampling_bigram_multinomial_confusion_matrix,
                      'Bigram Multinomial Naive Bayes with Oversampling \n for Minority Classes and 80% Testing Confusion Matrix',
                      savefilename='EightyBigramMultinomialOversamplingCM.png')
# Out:
# [[ 0.42367257  0.1460177   0.13827434  0.15984513  0.13219027]
#  [ 0.13627993  0.23143033  0.1995089   0.25966851  0.17311234]
#  [ 0.04324324  0.05971686  0.34877735  0.36499356  0.18326898]
#  [ 0.01636678  0.03019213  0.10236861  0.55514893  0.29592355]
#  [ 0.01780343  0.02024226  0.05097147  0.20217868  0.70880416]]

# %%
print_classifier_performance_metrics('Bigram Multinomial Naive Bayes Trained on Oversampling and 80% Test Data',
                                     eighty_oversampling_bigram_multinomial_nb_prediction)
# Out:
# MODEL: Bigram Multinomial Naive Bayes Trained on Oversampling and 80% Test Data
#
# Precision: 0.559400704948
# Recall: 0.566123557366
# F1: 0.562249153236
# Accuracy: 0.566123557366
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.50      0.42      0.46      1808
#      2 star       0.27      0.23      0.25      1629
#      3 star       0.38      0.35      0.36      3885
#      4 star       0.54      0.56      0.55      9837
#      5 star       0.68      0.71      0.69     12301
#
# avg / total       0.56      0.57      0.56     29460
#
#
# Precision variance: 0.098957
#
# Recall variance: 0.136684

# %% [markdown]
# ### Random Forest on 20% Training Data

# %%
TEST_SIZE = 0.20
train_X, test_X, train_y, test_y = train_test_split(df_with_initial_features_and_preprocessed_review_text.review_text,
                                                    df_with_initial_features_and_preprocessed_review_text.review_stars,
                                                    test_size=TEST_SIZE,
                                                    random_state=42)

# %%
forest100 = RandomForestClassifier(n_estimators = 100)

# %% [markdown]
# Transform Yelp Reviews into feature vectors

# %%
random_forest_feature_matrix_train = random_forest_vectorizer.fit_transform(train_X)
random_forest_feature_matrix_test = random_forest_vectorizer.transform(test_X)

# %% [markdown]
# Make predictions

# %%
# %time forest100.fit(random_forest_feature_matrix_train.toarray(), train_y)
forest100_pred = forest100.predict(random_forest_feature_matrix_test.toarray())
# Out:
# CPU times: user 4min 10s, sys: 280 ms, total: 4min 10s
# Wall time: 4min 11s

# %% [markdown]
# Visualize results in confusion matrix

# %%
random_forest_confusion_matrix = confusion_matrix(test_y, forest100_pred)
plot_confusion_matrix(random_forest_confusion_matrix, 'Random Forest (100 Learners) Confusion Matrix with 20% Training Data',
                      savefilename='TwentyRandomForestCM.png')

# %%
print_classifier_performance_metrics('Random Forest (100 Learners) with 20% Training Data', forest100_pred)
# Out:
# MODEL: Random Forest (100 Learners) with 20% Training Data
#
# Precision: 0.727378572977
# Recall: 0.713917175832
# F1: 0.702800124473
# Accuracy: 0.713917175832
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.73      0.59      0.65       449
#      2 star       0.83      0.31      0.45       391
#      3 star       0.81      0.42      0.55       989
#      4 star       0.63      0.76      0.69      2491
#      5 star       0.76      0.84      0.80      3045
#
# avg / total       0.73      0.71      0.70      7365
#
#
# Precision variance: 0.023577
#
# Recall variance: 0.199712

# %%
TEST_SIZE = 0.20
train_X, test_X, train_y, test_y = train_test_split(df_with_initial_features_and_preprocessed_review_text.review_text,
                                                    df_with_initial_features_and_preprocessed_review_text.review_stars,
                                                    test_size=TEST_SIZE,
                                                    random_state=42)

ONE_STAR_LABEL = 1
TWO_STAR_LABEL = 2
THREE_STAR_LABEL = 3
FOUR_STAR_LABEL = 4

one_star_reviews = train_X[train_y == ONE_STAR_LABEL]
two_star_reviews = train_X[train_y == TWO_STAR_LABEL]
three_star_reviews = train_X[train_y == THREE_STAR_LABEL]
four_star_reviews = train_X[train_y == FOUR_STAR_LABEL]

one_star_labels = train_y[train_y == ONE_STAR_LABEL]
two_star_labels = train_y[train_y == TWO_STAR_LABEL]
three_star_labels = train_y[train_y == THREE_STAR_LABEL]

difference_btw_number_of_4_and_1_stars = len(four_star_reviews) - len(one_star_reviews)
difference_btw_number_of_4_and_2_stars = len(four_star_reviews) - len(two_star_reviews)
difference_btw_number_of_4_and_3_stars = len(four_star_reviews) - len(three_star_reviews)

assert (np.array([difference_btw_number_of_4_and_1_stars,
                 difference_btw_number_of_4_and_2_stars,
                 difference_btw_number_of_4_and_3_stars]) > 0).all()

q1 = difference_btw_number_of_4_and_1_stars/len(one_star_reviews)
r1 = difference_btw_number_of_4_and_1_stars - len(one_star_reviews) * q1
q2 = difference_btw_number_of_4_and_2_stars/len(two_star_reviews)
r2 = difference_btw_number_of_4_and_2_stars - len(two_star_reviews) * q2
q3 = difference_btw_number_of_4_and_3_stars/len(three_star_reviews)
r3 = difference_btw_number_of_4_and_3_stars - len(three_star_reviews) * q3

train_X = np.vstack([np.reshape(train_X, (len(train_X), 1)),
                     np.tile(one_star_reviews, (1, q1)).T,
                     np.reshape(one_star_reviews[:r1], (r1, 1)),
                     np.tile(two_star_reviews, (1, q2)).T,
                     np.reshape(two_star_reviews[:r2], (r2, 1)),
                     np.tile(three_star_reviews, (1, q3)).T,
                     np.reshape(three_star_reviews[:r3], (r3, 1))])[:,0]

train_y = np.vstack([np.reshape(train_y, (len(train_y), 1)),
                     np.tile(one_star_labels, (1, q1)).T,
                     np.reshape(one_star_labels[:r1], (r1, 1)),
                     np.tile(two_star_labels, (1, q2)).T,
                     np.reshape(two_star_labels[:r2], (r2, 1)),
                     np.tile(three_star_labels, (1, q3)).T,
                     np.reshape(three_star_labels[:r3], (r3, 1))])[:,0]

# %%
random_forest_feature_matrix_train = random_forest_vectorizer.fit_transform(train_X)
random_forest_feature_matrix_test = random_forest_vectorizer.transform(test_X)

# %%
# %time forest100.fit(random_forest_feature_matrix_train.toarray(), train_y)
forest100_pred = forest100.predict(random_forest_feature_matrix_test.toarray())
# Out:
# CPU times: user 8min 36s, sys: 664 ms, total: 8min 37s
# Wall time: 8min 39s

# %%
random_forest_confusion_matrix = confusion_matrix(test_y, forest100_pred)
plot_confusion_matrix(random_forest_confusion_matrix, 'Random Forest (100 Learners) Confusion Matrix with 20% Training Data with Oversampling',
                      savefilename='TwentyOversamplingRandomForestCM.png')

# %%
print_classifier_performance_metrics('Random Forest (100 Learners) with 20% Training Data', forest100_pred)
# Out:
# MODEL: Random Forest (100 Learners) with 20% Training Data
#
# Precision: 0.705628157699
# Recall: 0.710522742702
# F1: 0.703904266397
# Accuracy: 0.710522742702
#
# Classification Report:
#              precision    recall  f1-score   support
#
#      1 star       0.62      0.70      0.66       449
#      2 star       0.62      0.39      0.48       391
#      3 star       0.66      0.49      0.57       989
#      4 star       0.69      0.69      0.69      2491
#      5 star       0.76      0.84      0.80      3045
#
# avg / total       0.71      0.71      0.70      7365
#
#
# Precision variance: 0.013862
#
# Recall variance: 0.130545

# %%
from datetime import datetime
import time

TURBO_DF.review_date = map(lambda datestring : datetime.strptime(datestring[:10], '%Y-%m-%d'), TURBO_DF.review_date)
TURBO_DF['review_timestamp'] = map(lambda date : int(time.mktime(date.timetuple())), TURBO_DF.review_date)

# %%
reviewtimestamps_count = TURBO_DF[['review_timestamp', 'review_id', 'review_date']].groupby('review_timestamp').count().review_id
DataFrame(reviewtimestamps_count).sort_index().to_json('reviewtimestamps_count.json')

# %%
with open ("reviewtimestamps_count.json", "r") as myfile:
    data=myfile.read().replace('\n', '')

# %%
from IPython.core.display import display, Javascript, HTML
import jinja2 as jin

t = jin.Template("""
<script type="text/javascript" src="//cdnjs.cloudflare.com/ajax/libs/moment.js/2.8.4/moment.js"></script>
<script type="text/javascript" src="//cdn.jsdelivr.net/cal-heatmap/3.3.10/cal-heatmap.min.js"></script>
<link rel="stylesheet" href="//cdn.jsdelivr.net/cal-heatmap/3.3.10/cal-heatmap.css" />

<h3>Yelp Reviews by Date in Years 2006-2014 from TURBO Subset</h3>

<div style="float:none; display: inline-block; margin-top: 20px; margin-right: 80px;">
    <button class="btn" id="prev">Prev 3 Years</button>
    <button class="btn" id="next">Next 3 Years</button>
</div>

<div id='title2009' style="display: inline-block; width=150px; margin-left: 80px, margin-right: 80px">2009</div>
<div id='title2010' style="display: inline-block; width=150px; margin-left: 240px ; margin-right: 80px">2010</div>
<div id='title2011' style="display: inline-block; width=150px; margin-left: 180px">2011</div>

<br />
<br />

<div id="cal-heatmap-2010" style="display: inline-block; width=100px;"></div>
<div id="cal-heatmap-2011" style="display: inline-block; width=80px;"></div>
<div id="cal-heatmap-2012" style="display: inline-block; width=80px;"></div>
<script type="text/javascript">
    var cal2009 = new CalHeatMap();
    cal2009.init({
    itemSelector: "#cal-heatmap-2010",
    itemName: ["Yelp review"],
    domain: "month",
    subDomain: "x_day",
    subDomainTitleFormat: {'empty': '>= 0 Yelp reviews on {date}', 'filled': '>= {count} {name} {connector} {date}'},
        data: {{data}},
    start: new Date(2009, 0, 5),
    cellSize: 20,
    cellPadding: 5,
    domainGutter: 20,
    range: 12,
    domainDynamicDimension: false,
    //previousSelector: "#cal-heatmap-PreviousDomain-selector",
    //nextSelector: "#cal-heatmap-NextDomain-selector",
    domainLabelFormat: function(date) {
        moment.lang("en");
        return moment(date).format("MMMM").toUpperCase();
    },
     legendColors: {
        empty: "#ededed",
        min: "#40ffd8",
        max: "#f20013"
    },
    subDomainTextFormat: "%d",
    weekStartOnMonday: false,
    verticalOrientation: true,
    legend: [5, 10, 15, 20, 25, 30, 35],
    label: {
        position: "left",
            offset: {
                x: 20,
                y: 35
            },
            width: 110
    },
    legendVerticalPosition: "center",
    legendMargin: [0,10,0,0]
});

var cal2010 = new CalHeatMap();
    cal2010.init({
    itemSelector: "#cal-heatmap-2011",
    itemName: ["Yelp review"],
    subDomainTitleFormat: {'empty': '>= 0 Yelp reviews on {date}', 'filled': '>= {count} {name} {connector} {date}'},
    domain: "month",
    domainLabelFormat: "",
    subDomain: "x_day",
        data: {{data}},
    start: new Date(2010, 0, 5),
    cellSize: 20,
    cellPadding: 5,
    domainGutter: 20,
    range: 12,
    domainDynamicDimension: false,
    //previousSelector: "#cal-heatmap-PreviousDomain-selector",
    //nextSelector: "#cal-heatmap-NextDomain-selector",
     legendColors: {
        empty: "#ededed",
        min: "#40ffd8",
        max: "#f20013"
    },
    displayLegend: false,
    subDomainTextFormat: "%d",
    weekStartOnMonday: false,
    verticalOrientation: true,
    legend: [5, 10, 15, 20, 25, 30, 35],
    label: {
        position: "left",
            offset: {
                x: 20,
                y: 35
            },
            width: 110
    },
});

var cal2011 = new CalHeatMap();
    cal2011.init({
    itemSelector: "#cal-heatmap-2012",
    itemName: ["Yelp review"],
    domain: "month",
    domainLabelFormat: "",
    subDomainTitleFormat: {'empty': '>= 0 Yelp reviews on {date}', 'filled': '>= {count} {name} {connector} {date}'},
    subDomain: "x_day",
        data: {{data}},
    start: new Date(2011, 0, 5),
    cellSize: 20,
    cellPadding: 5,
    domainGutter: 20,
    range: 12,
    domainDynamicDimension: false,
    //previousSelector: "#cal-heatmap-PreviousDomain-selector",
    //nextSelector: "#cal-heatmap-NextDomain-selector",
     legendColors: {
        empty: "#ededed",
        min: "#40ffd8",
        max: "#f20013"
    },
    subDomainTextFormat: "%d",
    weekStartOnMonday: false,
    verticalOrientation: true,
    legend: [5, 10, 15, 20, 25, 30],
    displayLegend: false,
    label: {
        position: "left",
            offset: {
                x: 20,
                y: 35
            },
            width: 110
    },
});

var three_cal_set_position = 1;
var thirty_six_months_in_three_years = 36;

$("#next").on("click", function(event) {
    three_cal_set_position = (three_cal_set_position + 1) % 3;
    
    if (three_cal_set_position == 0) {
        cal2009.jumpTo(new Date(2006, 0));
        cal2010.jumpTo(new Date(2007, 0));
        cal2011.jumpTo(new Date(2008, 0));
        $('div#title2009').text('2006');
        $('div#title2010').text('2007');
        $('div#title2011').text('2008');
    }
    else {
        cal2009.next(thirty_six_months_in_three_years);
        cal2010.next(thirty_six_months_in_three_years);
        cal2011.next(thirty_six_months_in_three_years);
        
        var text2009 = $('div#title2009').text();
        var text2010 = $('div#title2010').text();
        var text2011 = $('div#title2011').text();
        
        $('div#title2009').text(String(parseInt(text2009)+3));
        $('div#title2010').text(String(parseInt(text2010)+3));
        $('div#title2011').text(String(parseInt(text2011)+3));
    }
    
    
});

$("#prev").on("click", function(event) {
    three_cal_set_position = ((three_cal_set_position - 1)+3) % 3;
    
    if (three_cal_set_position == 2) {
        cal2009.jumpTo(new Date(2012, 0));
        cal2010.jumpTo(new Date(2013, 0));
        cal2011.jumpTo(new Date(2014, 0));
        $('div#title2009').text('2012');
        $('div#title2010').text('2013');
        $('div#title2011').text('2014');
    }
    else {
        cal2009.previous(thirty_six_months_in_three_years);
        cal2010.previous(thirty_six_months_in_three_years);
        cal2011.previous(thirty_six_months_in_three_years);
        
        var text2009 = $('div#title2009').text();
        var text2010 = $('div#title2010').text();
        var text2011 = $('div#title2011').text();
        
        $('div#title2009').text(String(parseInt(text2009)-3));
        $('div#title2010').text(String(parseInt(text2010)-3));
        $('div#title2011').text(String(parseInt(text2011)-3));
    }
});

</script>
""")

HTML("""
<script type="text/javascript" src="//cdn.jsdelivr.net/cal-heatmap/3.3.10/cal-heatmap.min.js"></script>
<script type="text/javascript" src="//cdnjs.cloudflare.com/ajax/libs/moment.js/2.8.4/moment.js"></script>
<link rel="stylesheet" href="//cdn.jsdelivr.net/cal-heatmap/3.3.10/cal-heatmap.css" />
""")

display(HTML(t.render({'data': data})))
# Out:
# <script type="text/javascript" src="//cdnjs.cloudflare.com/ajax/libs/moment.js/2.8.4/moment.js"></script>
# <script type="text/javascript" src="//cdn.jsdelivr.net/cal-heatmap/3.3.10/cal-heatmap.min.js"></script>
# <link rel="stylesheet" href="//cdn.jsdelivr.net/cal-heatmap/3.3.10/cal-heatmap.css" />
#
# <h3>Yelp Reviews by Date in Years 2006-2014 from TURBO Subset</h3>
#
# <div style="float:none; display: inline-block; margin-top: 20px; margin-right: 80px;">
#     <button class="btn" id="prev">Prev 3 Years</button>
#     <button class="btn" id="next">Next 3 Years</button>
# </div>
#
# <div id='title2009' style="display: inline-block; width=150px; margin-left: 80px, margin-right: 80px">2009</div>
# <div id='title2010' style="display: inline-block; width=150px; margin-left: 240px ; margin-right: 80px">2010</div>
# <div id='title2011' style="display: inline-block; width=150px; margin-left: 180px">2011</div>
#
# <br />
# <br />
#
# <div id="cal-heatmap-2010" style="display: inline-block; width=100px;"></div>
# <div id="cal-heatmap-2011" style="display: inline-block; width=80px;"></div>
# <div id="cal-heatmap-2012" style="display: inline-block; width=80px;"></div>
# <script type="text/javascript">
#     var cal2009 = new CalHeatMap();
#     cal2009.init({
#     itemSelector: "#cal-heatmap-2010",
#     itemName: ["Yelp review"],
#     domain: "month",
#     subDomain: "x_day",
#     subDomainTitleFormat: {'empty': '>= 0 Yelp reviews on {date}', 'filled': '>= {count} {name} {connector} {date}'},
#         data: {"1136620800":1,"1147503600":23,"1149318000":3,"1151564400":1,"1158044400":2,"1159254000":1,"1160204400":1,"1163664000":1,"1165564800":10,"1165824000":1,"1165910400":1,"1165996800":1,"1167206400":1,"1167811200":1,"1168502400":1,"1169539200":2,"1169625600":2,"1169971200":1,"1171526400":1,"1171699200":1,"1172390400":2,"1174201200":1,"1174287600":1,"1174892400":1,"1174978800":1,"1175065200":1,"1175670000":2,"1175842800":1,"1176102000":1,"1177138800":1,"1177484400":11,"1177657200":1,"1178002800":10,"1178348400":4,"1179126000":1,"1181199600":1,"1181890800":1,"1181977200":4,"1182150000":2,"1183359600":1,"1183446000":5,"1186470000":1,"1186642800":1,"1187161200":2,"1187247600":2,"1187938800":1,"1188198000":3,"1188457200":1,"1189062000":1,"1189494000":2,"1189753200":3,"1190012400":2,"1190444400":1,"1192258800":1,"1193382000":1,"1194336000":1,"1194854400":1,"1195286400":4,"1196150400":1,"1196668800":1,"1197360000":23,"1198137600":1,"1198483200":1,"1198656000":2,"1199001600":1,"1199347200":1,"1199433600":3,"1199606400":1,"1200988800":3,"1201420800":7,"1201593600":3,"1201680000":1,"1201939200":1,"1202457600":1,"1202544000":2,"1202630400":1,"1202976000":1,"1203580800":1,"1203926400":2,"1204012800":6,"1204099200":1,"1204185600":4,"1204358400":1,"1205132400":1,"1205391600":3,"1205478000":2,"1205564400":4,"1205823600":1,"1206428400":2,"1206774000":2,"1207033200":2,"1207206000":1,"1207292400":1,"1207551600":2,"1208156400":2,"1208588400":2,"1208847600":1,"1209279600":1,"1209366000":2,"1209625200":1,"1209798000":2,"1209970800":2,"1210230000":2,"1210489200":1,"1210575600":1,"1210921200":1,"1211958000":1,"1212217200":1,"1212390000":1,"1212562800":1,"1213081200":2,"1213167600":2,"1213254000":2,"1213340400":4,"1214204400":1,"1214290800":1,"1214377200":2,"1214636400":3,"1214722800":1,"1214809200":1,"1215068400":1,"1215500400":1,"1215586800":1,"1215673200":7,"1215846000":2,"1216018800":8,"1216450800":1,"1216537200":2,"1216623600":2,"1216710000":1,"1216882800":1,"1216969200":2,"1217055600":1,"1217142000":1,"1217228400":1,"1217314800":3,"1217401200":2,"1217487600":11,"1217574000":4,"1217660400":2,"1217746800":1,"1217833200":3,"1218092400":1,"1218178800":5,"1218351600":1,"1218524400":1,"1218610800":4,"1218697200":1,"1218783600":2,"1218870000":1,"1218956400":1,"1219474800":1,"1219647600":6,"1219734000":2,"1219820400":3,"1219993200":1,"1220252400":1,"1220338800":4,"1220425200":1,"1220598000":1,"1220684400":2,"1220770800":1,"1221202800":2,"1221289200":3,"1221375600":6,"1221548400":5,"1221634800":1,"1221807600":2,"1221894000":11,"1222066800":4,"1222326000":1,"1222412400":2,"1222930800":2,"1223103600":8,"1223190000":2,"1223276400":1,"1223622000":2,"1223794800":1,"1223967600":1,"1224486000":1,"1224831600":1,"1225090800":4,"1225177200":6,"1225609200":12,"1225699200":3,"1225785600":1,"1226217600":1,"1226390400":2,"1226476800":1,"1226736000":2,"1226822400":1,"1226995200":1,"1227168000":12,"1227427200":6,"1227600000":1,"1227686400":1,"1227859200":1,"1228118400":1,"1228204800":3,"1228377600":1,"1228464000":3,"1228809600":4,"1229155200":1,"1229241600":2,"1229328000":2,"1229414400":1,"1229673600":2,"1229760000":2,"1229932800":2,"1230019200":3,"1230278400":3,"1230364800":4,"1230537600":1,"1230710400":1,"1230796800":2,"1230883200":3,"1230969600":5,"1231142400":5,"1231315200":3,"1231401600":5,"1231574400":1,"1231660800":5,"1231747200":1,"1231833600":1,"1232092800":1,"1232265600":1,"1232438400":1,"1232524800":1,"1232611200":3,"1232870400":1,"1233043200":3,"1233216000":3,"1233388800":4,"1233561600":3,"1233648000":4,"1233734400":4,"1233820800":2,"1234080000":1,"1234339200":7,"1234512000":4,"1234684800":2,"1234771200":1,"1234857600":1,"1234944000":2,"1235376000":2,"1235635200":2,"1235721600":1,"1235894400":1,"1236067200":1,"1236153600":6,"1236240000":1,"1236326400":7,"1236927600":3,"1237014000":3,"1237100400":1,"1237186800":3,"1237359600":1,"1237618800":5,"1237705200":2,"1237791600":1,"1237964400":1,"1238050800":2,"1238137200":2,"1238310000":4,"1238396400":6," ...

# %%
thanksgiving_week_dr = []

for y in range(2006, 2015):
    thanksgiving_week_dr += map(lambda timestamp : timestamp.to_datetime(), pd.date_range(datetime(y, 11, 19), datetime(y, 11, 29)))
    
christmas_week_dr = []

for y in range(2006, 2015):
    christmas_week_dr += map(lambda timestamp : timestamp.to_datetime(), pd.date_range(datetime(y, 12, 18), datetime(y, 12, 31)))

# %% [markdown]
# Let's check on what Yelpers are doing during Thanksgiving and Christmas/New Year's season.

# %%
from collections import Counter
import re

common_english_words_series = DataFrame.from_csv('common_english_words_ordered_by_frequency.csv', index_col=None, header=None)[0]
some_common_english_words = set(common_english_words_series.values[:1200])

def filter_out_more_common_words(token_list):
    return filter(lambda tok : tok not in some_common_english_words, token_list)

def preprocess_but_dont_stem_string(s):
    s = remove_numbers_in_string(s)
    s = lowercase_remove_punctuation(s)
    s = remove_stopwords(s)
    token_list = nltk.word_tokenize(s)
    token_list = filter_out_more_stopwords(token_list)
    token_list = filter_out_more_common_words(token_list)
    return restring_tokens(token_list)

def bi_and_tri_gram_tokenizer(s):
    return [' '.join([t1, t2]) for (t1, t2) in bigrams(s.split())] + [' '.join([t1,t2,t3]) for (t1, t2, t3) in trigrams(s.split())]

# %% [markdown]
# Let's build a set of some foods, the names of which I got by downloading wikipedia articles and searching for the food lists.

# %%
food_txt = ''

with open ("food.txt", "r") as myfile:
    food_txt = myfile.read().replace('\n', '')
    myfile.close()
    
p = re.compile('•\s+(\w+)? (\w+)? (\w+)?')
trigram_food_words = p.findall(food_txt)
trigram_food_words = set(map(lambda trigram_tuple : ' '.join(trigram_tuple).lower().replace('list of ', ''), trigram_food_words))
Series(list(trigram_food_words)).to_csv('food_words.csv', index=None, header=None)

def search_food(q):
    for food in trigram_food_words:
        if q in food.split():
            yield food

def thanksgiving_text_has_food_word(text):
    
    def nonempty_search(word):
        match = 0

        for r in search_food(word):
            match += 1
            
            if match > 0:
                break
                
        return match > 0
    
    tokens = text.split()    
    return sum([nonempty_search(w) for w in tokens]) > len(tokens) * 0.25

# %%
list(search_food('tea'))[:10]
# Out:
# ['russian tea cakes',
#  'nuclear iced tea',
#  'bubble tea ',
#  'russian tea cake',
#  'sweet tea ',
#  'tea cakes ']

# %%
thanksgiving_week_text = TURBO_DF[TURBO_DF.review_date.isin(thanksgiving_week_dr)].review_text.values
thanksgiving_week_text = map(preprocess_but_dont_stem_string, thanksgiving_week_text)
thanksgiving_word_count_dict = reduce(lambda C, sentence : Counter(bi_and_tri_gram_tokenizer(sentence)) + C, thanksgiving_week_text, Counter())

# %%
phrases_with_foodlike_words = filter(thanksgiving_text_has_food_word, thanksgiving_word_count_dict.keys())
phrases_with_foodlike_words[:10]
# Out:
# ['vegetable sauce chicken',
#  'highly recommend pizza',
#  'noodle mountain chinatown',
#  'rice fried',
#  'creamy parmesan grits',
#  'breakfast burritos',
#  'planned fun',
#  'spicy awesome',
#  'rye bread pumpkin',
#  'mushroom crust soft']

# %%
foodlike_thanksgiving_words_count_dict = dict(map(lambda thanksgiving_word : (thanksgiving_word, thanksgiving_word_count_dict[thanksgiving_word]),
                                            phrases_with_foodlike_words))

# %%
Counter(foodlike_thanksgiving_words_count_dict)#.most_common(20)
# Out:
# Counter({'ice cream': 32, 'pad thai': 20, 'bleu cheese': 20, 'prime rib': 19, 'popcorn refill': 18, 'fried rice': 18, 'chips salsa': 14, 'im fan': 13, 'questions guys super': 12, 'super knowledgeable': 12, 'carne asada': 12, 'supply lived phoenix': 12, 'mashed potatoes': 12, 'soup cheese': 12, 'phoenix checker': 12, 'cheese bagel': 12, 'guys super knowledgeable': 12, 'lived phoenix checker': 12, 'phoenix checker pools': 12, 'guys super': 12, 'super knowledgeable helpful': 12, 'lived phoenix': 12, 'im totally': 12, 'soup cheese bagel': 12, 'fun friday': 11, 'karaoke fun friday': 11, 'frozen custard': 11, 'adjacent karaoke fun': 11, 'fun friday saturday': 11, 'karaoke fun': 11, 'bbq chicken': 11, 'super friendly': 11, 'sour cream': 11, 'frozen custard eggnog': 10, 'double sugar cone': 10, 'pumpkin thanksgiving': 10, 'jamie beer': 10, 'peppermint pumpkin': 10, 'peppermint pumpkin thanksgiving': 10, 'seasonhad double sugar': 10, 'beer casket': 10, 'cone eggnog peppermint': 10, 'sol bakery': 10, 'el sol bakery': 10, 'beer emily january': 10, 'custard eggnog peppermint': 10, 'eggnog peppermint pumpkin': 10, 'sugar cone eggnog': 10, 'cheese burger': 10, 'january jamie beer': 10, 'cone eggnog': 10, 'beer casket locals': 10, 'beer emily': 10, 'jamie beer casket': 10, 'bleu cheese burger': 10, 'sugar cone': 10, 'sweet corn': 10, 'el sol': 10, 'peppermint frozen custard': 10, 'thanksgiving feastaloha': 10, 'tis seasonhad double': 10, 'iced tea': 10, 'double sugar': 10, 'custard eggnog': 10, 'pumpkin thanksgiving feastaloha': 10, 'seasonhad double': 10, 'refill buck': 9, 'fantastic italian': 9, 'breakfast server friendly': 9, 'drink places shops': 9, 'stopped breakfast server': 9, 'makes flights prior': 9, 'popcorn refill popcorn': 9, 'overstuffed racks im': 9, 'souvenir drink': 9, 'purchase popcorn refill': 9, 'meal delivered fantastic': 9, 'im totally fan': 9, 'shops hate': 9, 'omelet sausage sauce': 9, 'loved meal delivered': 9, 'massive traffic jam': 9, 'flights prior flight': 9, 'foie gras': 9, 'racks im totally': 9, 'update stopped breakfast': 9, 'sausage sauce': 9, 'totally fan': 9, 'traffic jam': 9, 'places drink': 9, 'offers souvenir drink': 9, 'sauce carmines folks': 9, 'additionally purchase popcorn': 9, 'prior flight': 9, 'prior flight gate': 9, 'sausage sauce carmines': 9, 'loved meal': 9, 'breakfast server': 9, 'standing waiting': 9, 'drink places': 9, 'omelet sausage': 9, 'places drink places': 9, 'plenty places drink': 9, 'racks im': 9, 'flight standing waiting': 9, 'drink addition chairs': 9, 'stopped breakfast': 9, 'seats flight standing': 9, 'personable loved meal': 9, 'standing waiting flight': 9, 'buck drink addition': 9, 'sauce carmines': 9, 'refill buck drink': 9, 'totally fan mile': 9, 'buck drink': 9, 'jam humans tip': 9, 'fan mile easier': 9, 'places shops hate': 9, 'popcorn refill buck': 9, 'italian omelet sausage': 9, 'refill popcorn refill': 9, 'places shops': 9, 'delivered fantastic italian': 9, 'fantastic italian omelet': 9, 'drink cups refills': 9, 'flight standing': 9, 'flights prior': 9, 'purchase popcorn': 9, 'jam humans': 9, 'meal delivered': 9, 'italian omelet': 9, 'drink addition': 9, 'shops hate departure': 9, 'refill popcorn': 9, 'souvenir drink cups': 9, 'awesome pizza': 9, 'drink cups': 9, 'fan mile': 9, 'traffic jam humans': 9, 'monte carlo': 8, 'chicken soup': 8, 'pork plate': 8, 'cream cheese': 8, 'corned beef': 8, 'cooked perfection': 8, 'chicken noodle': 8, 'wine selection': 8, 'fries crispy': 8, 'roast beef': 7, 'quick bite': 7, 'highly recommended': 7, 'super cool': 7, 'chicken teriyaki': 7, 'potato salad': 7, 'border grill': 7, 'spam musubi': 7, 'consistent soup': 6, 'salad sandwiches': 6, 'ive prepared': 6, 'sandwiches alfalfa sprouts': 6, 'jk im': 6, 'awesome months rose': 6, 'cheese bagel yummy': 6, 'rose nails': 6, 'adobo fried rice': 6, 'asiago toasted potato': 6, 'cheese herb bagel': 6, 'cheese herb': 6, 'adobo fried': 6, 'turkey asiago toasted': 6, 'bagel chicken soup': 6, 'rice bea ...
